# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# In this project, you must apply EDA processes for the development of predictive models. Handling outliers, domain knowledge and feature engineering will be challenges.
#
# Also, this project aims to improve your ability to implement algorithms for Multi-Class Classification. Thus, you will have the opportunity to implement many algorithms commonly used for Multi-Class Classification problems.
#
# Before diving into the project, please take a look at the determines and tasks.

# %% [markdown]
# # Determines

# %% [markdown]
# The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#
# The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects.
#
#
# DATA DICT:
# https://data.world/datamil/ansur-ii-data-dictionary/workspace/file?filename=ANSUR+II+Databases+Overview.pdf
#
# ---
#
# To achieve high prediction success, you must understand the data well and develop different approaches that can affect the dependent variable.
#
# Firstly, try to understand the dataset column by column using pandas module. Do research within the scope of domain (body scales, and race characteristics) knowledge on the internet to get to know the data set in the fastest way.
#
# You will implement ***Logistic Regression, Support Vector Machine, XGBoost, Random Forest*** algorithms. Also, evaluate the success of your models with appropriate performance metrics.
#
# At the end of the project, choose the most successful model and try to enhance the scores with ***SMOTE*** make it ready to deploy. Furthermore, use ***SHAP*** to explain how the best model you choose works.

# %% [markdown]
# # Tasks

# %% [markdown]
# #### 1. Exploratory Data Analysis (EDA)
# - Import Libraries, Load Dataset, Exploring Data
#
#     *i. Import Libraries*
#
#     *ii. Ingest Data *
#
#     *iii. Explore Data*
#
#     *iv. Outlier Detection*
#
#     *v.  Drop unnecessary features*
#
# #### 2. Data Preprocessing
# - Scale (if needed)
# - Separete the data frame for evaluation purposes
#
# #### 3. Multi-class Classification
# - Import libraries
# - Implement SVM Classifer
# - Implement Decision Tree Classifier
# - Implement Random Forest Classifer
# - Implement XGBoost Classifer
# - Compare The Models

# %% [markdown]
# # EDA
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %% [markdown]
# ## Import Libraries
# Besides Numpy and Pandas, you need to import the necessary modules for data visualization, data preprocessing, Model building and tuning.
#
# *Note: Check out the course materials.*

# %%
# libraries for EDA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px
from sklearn.compose import make_column_transformer
import cufflinks as cf
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
#Enabling the offline mode for interactive plotting locally
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
#To display the plots
# %matplotlib inline

# sklearn library for machine learning algorithms, data preprocessing, and evaluation
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, log_loss, recall_score, accuracy_score, precision_score, f1_score

# yellowbrick library for visualizing the model performance
from yellowbrick.classifier import ConfusionMatrix
from yellowbrick.cluster import KElbowVisualizer 

from sklearn.pipeline import Pipeline
# to get rid of the warnings
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Ingest Data from links below and make a dataframe
# - Soldiers Male : https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr
# - Soldiers Female : https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq

# %%
soldiers_male = pd.read_csv('https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr', encoding='latin-1')
soldiers_female = pd.read_csv('https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq', encoding='latin-1')

# %% [markdown]
# ## Explore Data

# %%
soldiers_female.head()
# Out:
#    SubjectId  abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0      10037                             231            1282                    301                 204          1180                      222               177                373                        315               263               466                  65               338                        301                 141                  1011           223            836                587                     476                360             1336           274                 922         245         1095           759                    557                             310          35         65             16              220               713                     91         246                        316                         265                    517                432                 1028           75                182         184          141                548         191                     314           69         345                388                 966
# 1      10038                             194            1379                    320                 207          1292                      225               178                372                        272               250               430                  64               294                        270                 126                   893           186            900                583                     483                350             1440           261                 839         206         1234           835                    549                             329          32         60             23              208               726                     91         249                        341                         247                    468                463                 1117           78                187         189          138                535         180                     307           60         315                335                1048
# 2      10042                             183            1369                    329                 233          1271                      237               196                397                        300               276               450                  69               309                        270                 128                   987           204            861                583                     466                384             1451           287                 874         223         1226           821                    643                             374          36         65             26              204               790                    100         265                        343                         262                    488                469                 1060           84                198         195          146                588         207                     331           70         356                399                1043
# 3      10043                             261            1356                    306                 214          1250                      240               188                384                        364               276               484                  68               340                        294                 144                  1012           253            897                599                     471                372             1430           269                1008         285         1170           804                    640                             351          38         62             22              244               775                     97         265                        331                         309                    529                455                 1069           80                192         186          153                593         206                     332           68         337                402                1029
# 4      10051                             309            1303                    308                 214          1210                      217               182                378                        320               336               525                  67               300                        295                 135                  1281           284            811                607                     467                433             1362           305                1089         290         1112           726                    686                             356          34         65             18              233               732                     88         247                        339                         260                    596                447                 1039           78                183         187          140                522         181                     308           63         448                499                 964
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  weightkg  wristcircumference  wristheight  Gender      Date Installation     Component                  Branch PrimaryMOS SubjectsBirthLocation  SubjectNumericRace           Ethnicity  DODRace  Age  Heightin  Weightlbs WritingPreference
# 0                    645         363          399                   435                496                             447                      55                      404                  118                335                    368                           1268         113              362                   235                   1062                  327             148            803                     809            513  1647     1560                 1280            1013                 622             174            736           430               110                  844                           1488              406           295                 850         217                      345                   942       657                 152          756  Female  5-Oct-10    Fort Hood  Regular Army          Combat Support        92Y               Germany                   2                 NaN        2   26        61        142        Right hand
# 1                    595         340          375                   483                532                             492                      69                      334                  115                302                    345                           1389         110              426                   259                   1014                  346             142            835                     810            575  1751     1665                 1372            1107                 524             152            771           475               125                  901                           1470              422           254                 708         168                      329                  1032       534                 155          815  Female  5-Oct-10    Fort Hood  Regular Army  Combat Service Support        25U            California                   3             Mexican        3   21        64        120        Right hand
# 2                    655         345          399                   470                530                             469                      64                      401                  135                325                    369                           1414         122              398                   258                   1049                  362             164            904                     855            568  1779     1711                 1383            1089                 577             164            814           458               129                  882                           1542              419           269                 727         159                      367                  1035       663                 162          799  Female  5-Oct-10    Fort Hood  Regular Army  Combat Service Support        35D                 Texas                   1                 NaN        1   23        68        147        Right hand
# 3                    655         392          435                   469                520                             478                      67                      402                  118                357                    386                           1329         115              394                   250                   1121                  333             157            875                     815            536  1708     1660                 1358            1065                 679             187            736           463               125                  866                           1627              451           302                 923         235                      371                   999       782                 173          818  Female  5-Oct-10    Fort Hood  Regular Army  Combat Service Support        25U  District of Columbia                   8  Caribbean Islander        2   22        66        175        Right hand
# 4                    635         428          435                   440                491                             441                      63                      479                  114                340                    358                           1350         116              345                   242                   1151                  329             156            824                     810            559  1702     1572                 1292            1030                 766             197            766           429               116                  800                           1698              452           405                1163         300                      380                   911       886                 152          762  Female  5-Oct-10    Fort Hood  Regular Army             Combat Arms        42A                 Texas                   1                 NaN        1   45        63        195        Right hand

# %%
soldiers_male.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0      10027                             266            1467                    337                 222          1347                      253               202                401                        369               274               493                  71               319                        291                 142                   979           240            882                619                     509                373             1535           291                1074         259         1292           877                    607                             351          36         71             19              247               802                    101         273                        349                         299                    575                477                 1136           90                214         193          150                583         206                     326           70         332                366                1071
# 1      10032                             233            1395                    326                 220          1293                      245               193                394                        338               257               479                  67               344                        320                 135                   944           232            870                584                     468                357             1471           269                1021         253         1244           851                    615                             376          33         62             18              232               781                     98         263                        348                         289                    523                476                 1096           86                203         195          146                568         201                     334           72         312                356                1046
# 2      10033                             287            1430                    341                 230          1327                      256               196                427                        408               261               544                  75               345                        330                 135                  1054           258            901                623                     506                412             1501           288                1120         267         1288           854                    636                             359          40         61             23              237               810                    103         270                        355                         357                    575                491                 1115           93                220         203          148                573         202                     356           70         349                393                1053
# 3      10092                             234            1347                    310                 230          1239                      262               199                401                        359               262               518                  73               328                        309                 143                   991           242            821                560                     437                395             1423           296                1114         262         1205           769                    590                             341          39         66             25              272               794                    106         267                        352                         318                    593                467                 1034           91                217         194          158                576         199                     341           68         338                367                 986
# 4      10093                             250            1585                    372                 247          1478                      267               224                435                        356               263               524                  80               340                        310                 138                  1029           275           1080                706                     567                425             1684           304                1048         232         1452          1014                    682                             382          32         56             19              188               814                    111         305                        399                         324                    605                550                 1279           94                222         218          153                566         197                     374           69         332                372                1251
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  weightkg  wristcircumference  wristheight Gender       Date Installation     Component                  Branch PrimaryMOS SubjectsBirthLocation  SubjectNumericRace Ethnicity  DODRace  Age  Heightin  Weightlbs WritingPreference
# 0                    685         422          441                   502                560                             500                      77                      391                  118                400                    436                           1447         113              437                   273                   1151                  368             145            928                     883            600  1782     1776                 1449            1092                 610             164            786           491               140                  919                           1700              501           329                 933         240                      440                  1054       815                 175          853   Male   4-Oct-10    Fort Hood  Regular Army             Combat Arms        19D          North Dakota                   1       NaN        1   41        71        180        Right hand
# 1                    620         441          447                   490                540                             488                      73                      371                  131                380                    420                           1380         118              417                   254                   1119                  353             141            884                     868            564  1745     1702                 1387            1076                 572             169            822           476               120                  918                           1627              432           316                 870         225                      371                  1054       726                 167          815   Male   4-Oct-10    Fort Hood  Regular Army          Combat Support        68W              New York                   1       NaN        1   35        68        160         Left hand
# 2                    665         462          475                   496                556                             482                      72                      409                  123                403                    434                           1447         121              431                   268                   1276                  367             167            917                     910            604  1867     1735                 1438            1105                 685             198            807           477               125                  918                           1678              472           329                 964         255                      411                  1041       929                 180          831   Male   4-Oct-10    Fort Hood  Regular Army          Combat Support        68W              New York                   2       NaN        2   42        68        205         Left hand
# 3                    640         458          461                   460                511                             452                      76                      393                  106                407                    446                           1357         118              393                   249                   1155                  330             148            903                     848            550  1708     1655                 1346            1021                 604             180            803           445               127                  847                           1625              461           315                 857         205                      399                   968       794                 176          793   Male  12-Oct-10    Fort Hood  Regular Army  Combat Service Support        88M             Wisconsin                   1       NaN        1   31        66        175        Right hand
# 4                    675         481          505                   612                666                             585                      85                      458                  135                398                    430                           1572         132              523                   302                   1231                  400             180            919                     995            641  2035     1914                 1596            1292                 672             194            962           584               122                 1090                           1679              467           303                 868         214                      379                  1245       946                 188          954   Male  12-Oct-10    Fort Hood  Regular Army  Combat Service Support        92G        North Carolina                   2       NaN        2   21        77        213        Right hand

# %%
soldiers_female.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986 entries, 0 to 1985
# Columns: 108 entries, SubjectId to WritingPreference
# dtypes: int64(99), object(9)
# memory usage: 1.6+ MB

# %%
soldiers_male.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4082 entries, 0 to 4081
# Columns: 108 entries, subjectid to WritingPreference
# dtypes: int64(99), object(9)
# memory usage: 3.4+ MB

# %%
soldiers_female.shape
# Out:
# (1986, 108)

# %%
soldiers_male.shape
# Out:
# (4082, 108)

# %%
soldiers = pd.concat([soldiers_male, soldiers_female], axis=0, ignore_index= True)
soldiers
# Out:
#       subjectid  abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0       10027.0                             266            1467                    337                 222          1347                      253               202                401                        369               274               493                  71               319                        291                 142                   979           240            882                619                     509                373             1535           291                1074         259         1292           877                    607                             351          36         71             19              247               802                    101         273                        349                         299                    575                477                 1136           90                214         193          150                583         206                     326           70         332                366                1071
# 1       10032.0                             233            1395                    326                 220          1293                      245               193                394                        338               257               479                  67               344                        320                 135                   944           232            870                584                     468                357             1471           269                1021         253         1244           851                    615                             376          33         62             18              232               781                     98         263                        348                         289                    523                476                 1096           86                203         195          146                568         201                     334           72         312                356                1046
# 2       10033.0                             287            1430                    341                 230          1327                      256               196                427                        408               261               544                  75               345                        330                 135                  1054           258            901                623                     506                412             1501           288                1120         267         1288           854                    636                             359          40         61             23              237               810                    103         270                        355                         357                    575                491                 1115           93                220         203          148                573         202                     356           70         349                393                1053
# 3       10092.0                             234            1347                    310                 230          1239                      262               199                401                        359               262               518                  73               328                        309                 143                   991           242            821                560                     437                395             1423           296                1114         262         1205           769                    590                             341          39         66             25              272               794                    106         267                        352                         318                    593                467                 1034           91                217         194          158                576         199                     341           68         338                367                 986
# 4       10093.0                             250            1585                    372                 247          1478                      267               224                435                        356               263               524                  80               340                        310                 138                  1029           275           1080                706                     567                425             1684           304                1048         232         1452          1014                    682                             382          32         56             19              188               814                    111         305                        399                         324                    605                550                 1279           94                222         218          153                566         197                     374           69         332                372                1251
# ...         ...                             ...             ...                    ...                 ...           ...                      ...               ...                ...                        ...               ...               ...                 ...               ...                        ...                 ...                   ...           ...            ...                ...                     ...                ...              ...           ...                 ...         ...          ...           ...                    ...                             ...         ...        ...            ...              ...               ...                    ...         ...                        ...                         ...                    ...                ...                  ...          ...                ...         ...          ...                ...         ...                     ...          ...         ...                ...                 ...
# 6063        NaN                             285            1392                    335                 223          1297                      252               196                368                        299               312               477                  72               306                        282                 136                  1089           255            856                652                     541                373             1457           290                1082         293         1258           779                    732                             382          36         60             19              210               746                    103         259                        328                         262                    514                456                 1085           81                197         193          151                582         205                     321           75         381                413                1048
# 6064        NaN                             262            1324                    301                 202          1204                      236               181                378                        294               287               468                  66               309                        311                 145                  1016           246            818                572                     464                375             1390           291                1016         269         1151           732                    647                             331          36         65             23              274               770                    101         245                        319                         261                    514                440                  985           81                196         183          160                570         186                     296           61         347                377                 974
# 6065        NaN                             260            1334                    318                 213          1259                      234               183                363                        332               299               460                  70               317                        311                 139                  1063           262            846                637                     525                370             1412           285                1093         286         1166           793                    609                             326          39         62             18              204               739                     97         249                        338                         288                    530                459                 1050           82                192         191          144                559         190                     318           72         364                400                 986
# 6066        NaN                             205            1293                    302                 199          1207                      213               163                376                        276               280               426                  62               282                        267                 137                  1051           225            786                582                     480                370             1377           270                 922         243         1137           763                    575                             310          35         62             21              222               738                     91         226                        306                         258                    430                425                  995           74                177         176          149                558         186                     280           59         369                411                 971
# 6067        NaN                             238            1346                    308                 210          1256                      236               188                361                        285               279               433                  71               304                        278                 129                   974           217            820                586                     479                343             1401           272                 902         219         1186           783                    536                             307          35         58             23              243               754                    100         239                        314                         259                    464                439                 1053           78                187         177          148                561         189                     310           78         332                376                 994
#
#       interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  weightkg  wristcircumference  wristheight  Gender       Date Installation            Component                  Branch PrimaryMOS SubjectsBirthLocation  SubjectNumericRace Ethnicity  DODRace  Age  Heightin  Weightlbs WritingPreference  SubjectId
# 0                       685         422          441                   502                560                             500                      77                      391                  118                400                    436                           1447         113              437                   273                   1151                  368             145            928                     883            600  1782     1776                 1449            1092                 610             164            786           491               140                  919                           1700              501           329                 933         240                      440                  1054       815                 175          853    Male   4-Oct-10    Fort Hood         Regular Army             Combat Arms        19D          North Dakota                   1       NaN        1   41        71        180        Right hand        NaN
# 1                       620         441          447                   490                540                             488                      73                      371                  131                380                    420                           1380         118              417                   254                   1119                  353             141            884                     868            564  1745     1702                 1387            1076                 572             169            822           476               120                  918                           1627              432           316                 870         225                      371                  1054       726                 167          815    Male   4-Oct-10    Fort Hood         Regular Army          Combat Support        68W              New York                   1       NaN        1   35        68        160         Left hand        NaN
# 2                       665         462          475                   496                556                             482                      72                      409                  123                403                    434                           1447         121              431                   268                   1276                  367             167            917                     910            604  1867     1735                 1438            1105                 685             198            807           477               125                  918                           1678              472           329                 964         255                      411                  1041       929                 180          831    Male   4-Oct-10    Fort Hood         Regular Army          Combat Support        68W              New York                   2       NaN        2   42        68        205         Left hand        NaN
# 3                       640         458          461                   460                511                             452                      76                      393                  106                407                    446                           1357         118              393                   249                   1155                  330             148            903                     848            550  1708     1655                 1346            1021                 604             180            803           445               127                  847                           1625              461           315                 857         205                      399                   968       794                 176          793    Male  12-Oct-10    Fort Hood         Regular Army  Combat Service Support        88M             Wisconsin                   1       NaN        1   31        66        175        Right hand        NaN
# 4                       675         481          505                   612                666                             585                      85                      458                  135                398                    430                           1572         132              523                   302                   1231                  400             180            919                     995            641  2035     1914                 1596            1292                 672             194            962           584               122                 1090                           1679              467           303                 868         214                      379                  1245       946                 188          954    Male  12-Oct-10    Fort Hood         Regular Army  Combat Service Support        92G        North Carolina                   2       NaN        2   21        77        213        Right hand        NaN
# ...                     ...         ...          ...                   ...                ...                             ...                     ...                      ...                  ...                ...                    ...                            ...         ...              ...                   ...                    ...                  ...             ...            ...                     ...            ...   ...      ...                  ...             ...                 ...             ...            ...           ...               ...                  ...                            ...              ...           ...                 ...         ...                      ...                   ...       ...                 ...          ...     ...        ...          ...                  ...                     ...        ...                   ...                 ...       ...      ...  ...       ...        ...               ...        ...
# 6063                    615         373          390                   462                535                             486                      61                      423                  121                369                    391                           1307         118              414                   237                   1036                  354             145            865                     840            555  1716     1687                 1391            1119                 660             155            749           446               136                  872                           1706              447           334                1043         265                      370                  1002       832                 162          836  Female   5-Apr-12  Camp Shelby  Army National Guard          Combat Support        42A                 Texas                   3   Mexican        3   51        67        180        Right hand    29501.0
# 6064                    650         400          411                   433                483                             457                      58                      383                  130                359                    399                           1323          99              377                   237                   1051                  318             142            881                     794            525  1620     1613                 1316            1043                 616             157            721           422               131                  838                           1648              446           334                 971         243                      374                   958       717                 157          804  Female   5-Apr-12  Camp Shelby  Army National Guard          Combat Support        25U                 Texas                   3   Mexican        3   40        63        150        Right hand    29502.0
# 6065                    640         400          412                   450                517                             476                      57                      412                  111                352                    402                           1318         116              392                   259                   1054                  338             136            841                     848            566  1740     1644                 1337            1054                 640             159            758           449               127                  862                           1590              444           335                 982         254                      351                   970       762                 159          774  Female   5-Apr-12  Camp Shelby  Army National Guard          Combat Support        42A                 Texas                   2       NaN        2   40        66        168        Right hand    29503.0
# 6066                    640         383          418                   432                491                             445                      58                      400                  119                326                    380                           1286         111              375                   230                    996                  321             136            854                     791            530  1628     1616                 1288            1028                 623             163            725           419               135                  802                           1525              450           298                 837         208                      335                   952       632                 146          769  Female   5-Apr-12  Camp Shelby  Army National Guard          Combat Support        92Y                 Texas                   3   Mexican        3   31        63        133        Right hand    29511.0
# 6067                    595         333          373                   444                504                             445                      66                      372                  114                325                    381                           1372         112              390                   249                    997                  339             135            861                     821            542  1685     1641                 1334            1089                 592             162            762           436               130                  849                           1547              462           299                 891         223                      394                   943       610                 154          797  Female  28-May-11   Fort McCoy  Army National Guard          Combat Support        92F                 Texas                   3   Mexican        3   27        66        132        Right hand   920103.0
#
# [6068 rows x 109 columns]

# %%
soldiers.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6068 entries, 0 to 6067
# Data columns (total 109 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    subjectid                       float64
#  1    abdominalextensiondepthsitting  int64
#  2    acromialheight                  int64
#  3    acromionradialelength           int64
#  4    anklecircumference              int64
#  5    axillaheight                    int64
#  6    balloffootcircumference         int64
#  7    balloffootlength                int64
#  8    biacromialbreadth               int64
#  9    bicepscircumferenceflexed       int64
#  10   bicristalbreadth                int64
#  11   bideltoidbreadth                int64
#  12   bimalleolarbreadth              int64
#  13   bitragionchinarc                int64
#  14   bitragionsubmandibulararc       int64
#  15   bizygomaticbreadth              int64
#  16   buttockcircumference            int64
#  17   buttockdepth                    int64
#  18   buttockheight                   int64
#  19   buttockkneelength               int64
#  20   buttockpopliteallength          int64
#  21   calfcircumference               int64
#  22   cervicaleheight                 int64
#  23   chestbreadth                    int64
#  24   chestcircumference              int64
#  25   chestdepth                      int64
#  26   chestheight                     int64
#  27   crotchheight                    int64
#  28   crotchlengthomphalion           int64
#  29   crotchlengthposterioromphalion  int64
#  30   earbreadth                      int64
#  31   earlength                       int64
#  32   earprotrusion                   int64
#  33   elbowrestheight                 int64
#  34   eyeheightsitting                int64
#  35   footbreadthhorizontal           int64
#  36   footlength                      int64
#  37   forearmcenterofgriplength       int64
#  38   forearmcircumferenceflexed      int64
#  39   forearmforearmbreadth           int64
#  40   forearmhandlength               int64
#  41   functionalleglength             int64
#  42   handbreadth                     int64
#  43   handcircumference               int64
#  44   handlength                      int64
#  45   headbreadth                     int64
#  46   headcircumference               int64
#  47   headlength                      int64
#  48   heelanklecircumference          int64
#  49   heelbreadth                     int64
#  50   hipbreadth                      int64
#  51   hipbreadthsitting               int64
#  52   iliocristaleheight              int64
#  53   interpupillarybreadth           int64
#  54   interscyei                      int64
#  55   interscyeii                     int64
#  56   kneeheightmidpatella            int64
#  57   kneeheightsitting               int64
#  58   lateralfemoralepicondyleheight  int64
#  59   lateralmalleolusheight          int64
#  60   lowerthighcircumference         int64
#  61   mentonsellionlength             int64
#  62   neckcircumference               int64
#  63   neckcircumferencebase           int64
#  64   overheadfingertipreachsitting   int64
#  65   palmlength                      int64
#  66   poplitealheight                 int64
#  67   radialestylionlength            int64
#  68   shouldercircumference           int64
#  69   shoulderelbowlength             int64
#  70   shoulderlength                  int64
#  71   sittingheight                   int64
#  72   sleevelengthspinewrist          int64
#  73   sleeveoutseam                   int64
#  74   span                            int64
#  75   stature                         int64
#  76   suprasternaleheight             int64
#  77   tenthribheight                  int64
#  78   thighcircumference              int64
#  79   thighclearance                  int64
#  80   thumbtipreach                   int64
#  81   tibialheight                    int64
#  82   tragiontopofhead                int64
#  83   trochanterionheight             int64
#  84   verticaltrunkcircumferenceusa   int64
#  85   waistbacklength                 int64
#  86   waistbreadth                    int64
#  87   waistcircumference              int64
#  88   waistdepth                      int64
#  89   waistfrontlengthsitting         int64
#  90   waistheightomphalion            int64
#  91   weightkg                        int64
#  92   wristcircumference              int64
#  93   wristheight                     int64
#  94   Gender                          object
#  95   Date                            object
#  96   Installation                    object
#  97   Component                       object
#  98   Branch                          object
#  99   PrimaryMOS                      object
#  100  SubjectsBirthLocation           object
#  101  SubjectNumericRace              int64
#  102  Ethnicity                       object
#  103  DODRace                         int64
#  104  Age                             int64
#  105  Heightin                        int64
#  106  Weightlbs                       int64
#  107  WritingPreference               object
#  108  SubjectId                       float64
# dtypes: float64(2), int64(98), object(9)
# memory usage: 5.0+ MB

# %%
soldiers.describe().T
# Out:
#                                  count          mean           std      min       25%      50%       75%       max
# subjectid                       4082.0  20003.370897   6568.435122  10027.0  14270.25  17236.5  27315.75   29452.0
# abdominalextensiondepthsitting  6068.0    246.468688     37.400106    155.0    219.00    242.0    271.00     451.0
# acromialheight                  6068.0   1406.161338     79.091048   1115.0   1350.00   1410.0   1462.00    1683.0
# acromionradialelength           6068.0    327.374423     20.720018    249.0    313.00    328.0    341.25     393.0
# anklecircumference              6068.0    224.891397     16.051833    156.0    214.00    225.0    235.00     293.0
# axillaheight                    6068.0   1299.608767     72.022286   1038.0   1249.00   1302.0   1349.00    1553.0
# balloffootcircumference         6068.0    244.192650     16.845020    186.0    232.00    245.0    256.00     306.0
# lateralfemoralepicondyleheight    0.000000
# kneeheightsitting                 0.000000
# kneeheightmidpatella              0.000000
# interscyeii                       0.000000
# palmlength                        0.000000
# thighcircumference                0.000000
# thighclearance                    0.000000
# thumbtipreach                     0.000000
# DODRace                           0.000000
# Weightlbs                         0.000000
# SubjectNumericRace                0.000000
# SubjectsBirthLocation             0.000000
# PrimaryMOS                        0.000000
# Branch                            0.000000
# Component                         0.000000
# Installation                      0.000000
# Date                              0.000000
# Gender                            0.000000
# wristheight                       0.000000
# wristcircumference                0.000000
# weightkg                          0.000000
# waistheightomphalion              0.000000
# waistfrontlengthsitting           0.000000
# waistdepth                        0.000000
# waistcircumference                0.000000
# waistbreadth                      0.000000
# waistbacklength                   0.000000
# verticaltrunkcircumferenceusa     0.000000
# trochanterionheight               0.000000
# tragiontopofhead                  0.000000
# tibialheight                      0.000000
# WritingPreference                 0.000000
# interpupillarybreadth             0.000000
# iliocristaleheight                0.000000
# hipbreadthsitting                 0.000000
# chestbreadth                      0.000000
# cervicaleheight                   0.000000
# calfcircumference                 0.000000
# buttockpopliteallength            0.000000
# buttockkneelength                 0.000000
# buttockheight                     0.000000
# buttockdepth                      0.000000
# buttockcircumference              0.000000
# bizygomaticbreadth                0.000000
# bitragionsubmandibulararc         0.000000
# bitragionchinarc                  0.000000
# bimalleolarbreadth                0.000000
# bideltoidbreadth                  0.000000
# bicristalbreadth                  0.000000
# bicepscircumferenceflexed         0.000000
# biacromialbreadth                 0.000000
# balloffootlength                  0.000000
# balloffootcircumference           0.000000
# axillaheight                      0.000000
# anklecircumference                0.000000
# acromionradialelength             0.000000
# acromialheight                    0.000000
# abdominalextensiondepthsitting    0.000000
# chestcircumference                0.000000
# Age                               0.000000
# chestdepth                        0.000000
# crotchheight                      0.000000
# hipbreadth                        0.000000
# heelbreadth                       0.000000
# heelanklecircumference            0.000000
# headlength                        0.000000
# headcircumference                 0.000000
# headbreadth                       0.000000
# handlength                        0.000000
# handcircumference                 0.000000
# handbreadth                       0.000000
# functionalleglength               0.000000
# forearmhandlength                 0.000000
# forearmforearmbreadth             0.000000
# forearmcircumferenceflexed        0.000000
# forearmcenterofgriplength         0.000000
# footlength                        0.000000
# footbreadthhorizontal             0.000000
# eyeheightsitting                  0.000000
# elbowrestheight                   0.000000
# earprotrusion                     0.000000
# earlength                         0.000000
# earbreadth                        0.000000
# crotchlengthposterioromphalion    0.000000
# crotchlengthomphalion             0.000000
# chestheight                       0.000000
# Heightin                          0.000000
# subjectid                         0.327291
# SubjectId                         0.672709
# Ethnicity                         0.765821
# dtype: float64

# %%
soldiers.drop(['SubjectId', 'subjectid'], axis=1, inplace=True)

# %%
soldiers.duplicated().sum()
# Out:
# 0

# %%
soldiers['Ethnicity'].value_counts(dropna=False, normalize=True)
# Out:
# NaN                                                   0.765821
# Mexican                                               0.058833
# Puerto Rican                                          0.030158
# Caribbean Islander                                    0.020435
# Filipino                                              0.011042
# Cherokee                                              0.010712
# Korean                                                0.008734
# Dominican                                             0.005274
# Caribbean Islander Cherokee                           0.000165
# Nicaraguan Salvadoran                                 0.000165
# Guatemalan Puerto Rican                               0.000165
# Chinese Korean                                        0.000165
# Armenian                                              0.000165
# Caribbean Islander Cuban                              0.000165
# Arab or Middle Eastern Cuban                          0.000165
# Oneida                                                0.000165
# Chinese Japanese                                      0.000165
# Filipino Hawaiian Puerto Rican                        0.000165
# Dominican Ecuadorian Puerto Rican                     0.000165
# Caribbean Islander Mexican                            0.000165
# Cuban Laotian                                         0.000165
# Filipino Japanese                                     0.000165
# Filipino Hawaiian Japanese                            0.000165
# Japanese Korean                                       0.000165
# Indonesian Puerto Rican                               0.000165
# Cherokee Osage                                        0.000165
# Laguna Pueblo Mexican Puerto Rican                    0.000165
# Mexican Panamanian                                    0.000165
# Colombian Puerto Rican                                0.000165
# Costa Rican                                           0.000165
# Cambodian Vietnamese                                  0.000165
# Turkish                                               0.000165
# Filipino Korean                                       0.000165
# Blackfoot Mexican                                     0.000165
# Lakota Sioux                                          0.000165
# Cuban Salvadoran                                      0.000165
# Caribbean Islander Dominican                          0.000165
# Azorean                                               0.000165
# Apache Blackfoot Cherokee Crow                        0.000165
# Name: Ethnicity, dtype: float64

# %%
soldiers.drop(['Ethnicity'], axis=1, inplace=True)

# %%
soldiers.shape
# Out:
# (6068, 106)

# %%
soldiers.corrwith(soldiers['DODRace']).sort_values(ascending=False)
# Out:
# DODRace                           1.000000
# interpupillarybreadth             0.140017
# bizygomaticbreadth                0.100792
# heelbreadth                       0.076786
# headbreadth                       0.055987
# bitragionchinarc                  0.047683
# SubjectNumericRace                0.017987
# Age                               0.004738
# bitragionsubmandibulararc        -0.020004
# tragiontopofhead                 -0.021191
# earprotrusion                    -0.029490
# lowerthighcircumference          -0.037853
# thighcircumference               -0.042693
# earlength                        -0.042940
# mentonsellionlength              -0.044308
# footbreadthhorizontal            -0.053260
# headcircumference                -0.054221
# thighclearance                   -0.060196
# buttockdepth                     -0.063854
# hipbreadthsitting                -0.065287
# bicepscircumferenceflexed        -0.066587
# palmlength                       -0.074414
# chestdepth                       -0.077655
# shoulderlength                   -0.078830
# earbreadth                       -0.079089
# abdominalextensiondepthsitting   -0.079167
# waistdepth                       -0.082569
# calfcircumference                -0.084525
# handlength                       -0.085055
# buttockcircumference             -0.085927
# radialestylionlength             -0.089997
# bideltoidbreadth                 -0.093332
# waistcircumference               -0.103039
# forearmforearmbreadth            -0.103049
# hipbreadth                       -0.106097
# forearmcenterofgriplength        -0.106362
# balloffootcircumference          -0.108116
# forearmhandlength                -0.108761
# shouldercircumference            -0.109300
# thumbtipreach                    -0.113070
# balloffootlength                 -0.113672
# chestcircumference               -0.113826
# neckcircumference                -0.116210
# bimalleolarbreadth               -0.116689
# forearmcircumferenceflexed       -0.118351
# elbowrestheight                  -0.119390
# footlength                       -0.121801
# biacromialbreadth                -0.124767
# crotchlengthomphalion            -0.129514
# heelanklecircumference           -0.129768
# interscyei                       -0.130775
# neckcircumferencebase            -0.131368
# waistbreadth                     -0.132314
# span                             -0.132347
# weightkg                         -0.133350
# interscyeii                      -0.133428
# Weightlbs                        -0.135988
# waistfrontlengthsitting          -0.140695
# crotchlengthposterioromphalion   -0.146328
# sleeveoutseam                    -0.148967
# buttockpopliteallength           -0.150563
# chestbreadth                     -0.157602
# bicristalbreadth                 -0.157624
# anklecircumference               -0.158360
# handcircumference                -0.163543
# sleevelengthspinewrist           -0.165493
# buttockkneelength                -0.165800
# lateralfemoralepicondyleheight   -0.167519
# buttockheight                    -0.167929
# kneeheightmidpatella             -0.168789
# handbreadth                      -0.170150
# trochanterionheight              -0.171156
# headlength                       -0.175424
# functionalleglength              -0.176545
# waistbacklength                  -0.176928
# crotchheight                     -0.177346
# tibialheight                     -0.179843
# kneeheightsitting                -0.181122
# wristcircumference               -0.181502
# overheadfingertipreachsitting    -0.184169
# poplitealheight                  -0.185394
# verticaltrunkcircumferenceusa    -0.193644
# tenthribheight                   -0.200718
# acromionradialelength            -0.201095
# iliocristaleheight               -0.202265
# shoulderelbowlength              -0.210386
# chestheight                      -0.211777
# waistheightomphalion             -0.212210
# lateralmalleolusheight           -0.216845
# suprasternaleheight              -0.225953
# Heightin                         -0.227227
# cervicaleheight                  -0.228369
# axillaheight                     -0.229070
# acromialheight                   -0.235121
# stature                          -0.237380
# eyeheightsitting                 -0.251502
# sittingheight                    -0.252029
# wristheight                      -0.257819
# dtype: float64

# %%
soldiers.columns
# Out:
# Index(['abdominalextensiondepthsitting', 'acromialheight', 'acromionradialelength', 'anklecircumference', 'axillaheight', 'balloffootcircumference', 'balloffootlength', 'biacromialbreadth', 'bicepscircumferenceflexed', 'bicristalbreadth',
#        ...
#        'Component', 'Branch', 'PrimaryMOS', 'SubjectsBirthLocation', 'SubjectNumericRace', 'DODRace', 'Age', 'Heightin', 'Weightlbs', 'WritingPreference'], dtype='object', length=106)

# %%
soldiers['DODRace'].value_counts().plot(kind='bar');

# %%
soldiers['DODRace'] = soldiers['DODRace'].map({1: 'White',
                  2: 'Black',
                  3: 'Hispanic',
                  4: 'Asian',
                  5: 'Native_American',
                  6: 'Pacific_Islander',
                  8: 'Other'})

# %%
soldiers['DODRace'].value_counts()
# Out:
# White               3792
# Black               1298
# Hispanic             679
# Asian                188
# Pacific_Islander      59
# Native_American       49
# Other                  3
# Name: DODRace, dtype: int64

# %%
soldiers.Gender
# Out:
# 0         Male
# 1         Male
# 2         Male
# 3         Male
# 4         Male
#          ...
# 6063    Female
# 6064    Female
# 6065    Female
# 6066    Female
# 6067    Female
# Name: Gender, Length: 6068, dtype: object

# %%
soldiers2 = soldiers[(soldiers['DODRace']=='White')|(soldiers['DODRace']=='Black')| (soldiers['DODRace']=='Hispanic')]

# %%
soldiers2.reset_index(drop = True, inplace = True)
soldiers2
# Out:
#       abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0                                266            1467                    337                 222          1347                      253               202                401                        369               274               493                  71               319                        291                 142                   979           240            882                619                     509                373             1535           291                1074         259         1292           877                    607                             351          36         71             19              247               802                    101         273                        349                         299                    575                477                 1136           90                214         193          150                583         206                     326           70         332                366                1071
# 1                                233            1395                    326                 220          1293                      245               193                394                        338               257               479                  67               344                        320                 135                   944           232            870                584                     468                357             1471           269                1021         253         1244           851                    615                             376          33         62             18              232               781                     98         263                        348                         289                    523                476                 1096           86                203         195          146                568         201                     334           72         312                356                1046
# 2                                287            1430                    341                 230          1327                      256               196                427                        408               261               544                  75               345                        330                 135                  1054           258            901                623                     506                412             1501           288                1120         267         1288           854                    636                             359          40         61             23              237               810                    103         270                        355                         357                    575                491                 1115           93                220         203          148                573         202                     356           70         349                393                1053
# 3                                234            1347                    310                 230          1239                      262               199                401                        359               262               518                  73               328                        309                 143                   991           242            821                560                     437                395             1423           296                1114         262         1205           769                    590                             341          39         66             25              272               794                    106         267                        352                         318                    593                467                 1034           91                217         194          158                576         199                     341           68         338                367                 986
# 4                                250            1585                    372                 247          1478                      267               224                435                        356               263               524                  80               340                        310                 138                  1029           275           1080                706                     567                425             1684           304                1048         232         1452          1014                    682                             382          32         56             19              188               814                    111         305                        399                         324                    605                550                 1279           94                222         218          153                566         197                     374           69         332                372                1251
# ...                              ...             ...                    ...                 ...           ...                      ...               ...                ...                        ...               ...               ...                 ...               ...                        ...                 ...                   ...           ...            ...                ...                     ...                ...              ...           ...                 ...         ...          ...           ...                    ...                             ...         ...        ...            ...              ...               ...                    ...         ...                        ...                         ...                    ...                ...                  ...          ...                ...         ...          ...                ...         ...                     ...          ...         ...                ...                 ...
# 5764                             285            1392                    335                 223          1297                      252               196                368                        299               312               477                  72               306                        282                 136                  1089           255            856                652                     541                373             1457           290                1082         293         1258           779                    732                             382          36         60             19              210               746                    103         259                        328                         262                    514                456                 1085           81                197         193          151                582         205                     321           75         381                413                1048
# 5765                             262            1324                    301                 202          1204                      236               181                378                        294               287               468                  66               309                        311                 145                  1016           246            818                572                     464                375             1390           291                1016         269         1151           732                    647                             331          36         65             23              274               770                    101         245                        319                         261                    514                440                  985           81                196         183          160                570         186                     296           61         347                377                 974
male   4-Oct-10    Fort Hood         Regular Army          Combat Support        68W              New York     White         Left hand
# 2       Male   4-Oct-10    Fort Hood         Regular Army          Combat Support        68W              New York     Black         Left hand
# 3       Male  12-Oct-10    Fort Hood         Regular Army  Combat Service Support        88M             Wisconsin     White        Right hand
# 4       Male  12-Oct-10    Fort Hood         Regular Army  Combat Service Support        92G        North Carolina     Black        Right hand
# ...      ...        ...          ...                  ...                     ...        ...                   ...       ...               ...
# 5764  Female   5-Apr-12  Camp Shelby  Army National Guard          Combat Support        42A                 Texas  Hispanic        Right hand
# 5765  Female   5-Apr-12  Camp Shelby  Army National Guard          Combat Support        25U                 Texas  Hispanic        Right hand
# 5766  Female   5-Apr-12  Camp Shelby  Army National Guard          Combat Support        42A                 Texas     Black        Right hand
# 5767  Female   5-Apr-12  Camp Shelby  Army National Guard          Combat Support        92Y                 Texas  Hispanic        Right hand
# 5768  Female  28-May-11   Fort McCoy  Army National Guard          Combat Support        92F                 Texas  Hispanic        Right hand
#
# [5769 rows x 9 columns]

# %%
soldiers2.drop(['Date', 'PrimaryMOS', 'WritingPreference', "Installation","Component", "Branch"], inplace = True, axis = 1)

# %%
soldiers2.select_dtypes('object')
# Out:
#       Gender SubjectsBirthLocation   DODRace
# 0       Male          North Dakota     White
# 1       Male              New York     White
# 2       Male              New York     Black
# 3       Male             Wisconsin     White
# 4       Male        North Carolina     Black
# ...      ...                   ...       ...
# 5764  Female                 Texas  Hispanic
# 5765  Female                 Texas  Hispanic
# 5766  Female                 Texas     Black
# 5767  Female                 Texas  Hispanic
# 5768  Female                 Texas  Hispanic
#
# [5769 rows x 3 columns]

# %%
soldiers2.weightkg/10
# Out:
# 0       81.5
# 1       72.6
# 2       92.9
# 3       79.4
# 4       94.6
#         ...
# 5764    83.2
# 5765    71.7
# 5766    76.2
# 5767    63.2
# 5768    61.0
# Name: weightkg, Length: 5769, dtype: float64

# %%
soldiers2.drop(['Heightin', 'Weightlbs'], axis=1, inplace=True)

# %%
soldiers2.head()
# Out:
#    abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0                             266            1467                    337                 222          1347                      253               202                401                        369               274               493                  71               319                        291                 142                   979           240            882                619                     509                373             1535           291                1074         259         1292           877                    607                             351          36         71             19              247               802                    101         273                        349                         299                    575                477                 1136           90                214         193          150                583         206                     326           70         332                366                1071
# 1                             233            1395                    326                 220          1293                      245               193                394                        338               257               479                  67               344                        320                 135                   944           232            870                584                     468                357             1471           269                1021         253         1244           851                    615                             376          33         62             18              232               781                     98         263                        348                         289                    523                476                 1096           86                203         195          146                568         201                     334           72         312                356                1046
# 2                             287            1430                    341                 230          1327                      256               196                427                        408               261               544                  75               345                        330                 135                  1054           258            901                623                     506                412             1501           288                1120         267         1288           854                    636                             359          40         61             23              237               810                    103         270                        355                         357                    575                491                 1115           93                220         203          148                573         202                     356           70         349                393                1053
# 3                             234            1347                    310                 230          1239                      262               199                401                        359               262               518                  73               328                        309                 143                   991           242            821                560                     437                395             1423           296                1114         262         1205           769                    590                             341          39         66             25              272               794                    106         267                        352                         318                    593                467                 1034           91                217         194          158                576         199                     341           68         338                367                 986
# 4                             250            1585                    372                 247          1478                      267               224                435                        356               263               524                  80               340                        310                 138                  1029           275           1080                706                     567                425             1684           304                1048         232         1452          1014                    682                             382          32         56             19              188               814                    111         305                        399                         324                    605                550                 1279           94                222         218          153                566         197                     374           69         332                372                1251
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  weightkg  wristcircumference  wristheight Gender SubjectsBirthLocation  SubjectNumericRace DODRace  Age
# 0                    685         422          441                   502                560                             500                      77                      391                  118                400                    436                           1447         113              437                   273                   1151                  368             145            928                     883            600  1782     1776                 1449            1092                 610             164            786           491               140                  919                           1700              501           329                 933         240                      440                  1054       815                 175          853   Male          North Dakota                   1   White   41
# 1                    620         441          447                   490                540                             488                      73                      371                  131                380                    420                           1380         118              417                   254                   1119                  353             141            884                     868            564  1745     1702                 1387            1076                 572             169            822           476               120                  918                           1627              432           316                 870         225                      371                  1054       726                 167          815   Male              New York                   1   White   35
# 2                    665         462          475                   496                556                             482                      72                      409                  123                403                    434                           1447         121              431                   268                   1276                  367             167            917                     910            604  1867     1735                 1438            1105                 685             198            807           477               125                  918                           1678              472           329                 964         255                      411                  1041       929                 180          831   Male              New York                   2   Black   42
# 3                    640         458          461                   460                511                             452                      76                      393                  106                407                    446                           1357         118              393                   249                   1155                  330             148            903                     848            550  1708     1655                 1346            1021                 604             180            803           445               127                  847                           1625              461           315                 857         205                      399                   968       794                 176          793   Male             Wisconsin                   1   White   31
# 4                    675         481          505                   612                666                             585                      85                      458                  135                398                    430                           1572         132              523                   302                   1231                  400             180            919                     995            641  2035     1914                 1596            1292                 672             194            962           584               122                 1090                           1679              467           303                 868         214                      379                  1245       946                 188          954   Male        North Carolina                   2   Black   21

# %% [markdown]
# # DATA Preprocessing
# - In this step we divide our data to X(Features) and y(Target) then ,
# - To train and evaluation purposes we create train and test sets,
# - Lastly, scale our data if features not in same scale. Why?

# %%
X = soldiers2.drop('DODRace', axis=1)
y = soldiers2['DODRace']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101, stratify=y)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.compose import ColumnTransformer

def trans_2(X_train, X_test):
    
    cat = X_train.select_dtypes("object").columns
    cat = list(cat)
    
    enc = OneHotEncoder(handle_unknown="ignore", sparse=False)
    
    X_train_cat = pd.DataFrame(enc.fit_transform(X_train[cat]), index = X_train.index, 
                           columns = enc.get_feature_names_out(cat))
    
    X_test_cat  = pd.DataFrame(enc.transform(X_test[cat]), index = X_test.index, 
                               columns = enc.get_feature_names_out(cat))
    
    X_train = X_train_cat.join(X_train.select_dtypes("number"))
    X_test = X_test_cat.join(X_test.select_dtypes("number"))
    
    
    return X_train, X_test

# %%
X_train, X_test = trans_2(X_train, X_test)

# %%
print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (4615, 225)
# Train target shape   :  (4615,)
# Test features shape  :  (1154, 225)
# Test target shape    :  (1154,)

# %%
#!pip install -U scikit-learn

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, StandardScaler

column_trans = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), list(X_train.select_dtypes("object").columns)), 
                                       remainder=MinMaxScaler())

# %% [markdown]
# # Modelling
# - Fit the model with train dataset
# - Get predict from vanilla model on both train and test sets to examine if there is over/underfitting
# - Apply GridseachCV for both hyperparemeter tuning and sanity test of our model.
# - Use hyperparameters that you find from gridsearch and make final prediction and evaluate the result according to chosen metric.

# %% [markdown]
# ## 1. Logistic model

# %% [markdown]
# ### Vanilla Logistic Model

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
from sklearn.pipeline import Pipeline
operations = [("OneHotEncoder", column_trans), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,
                                                                          random_state=101))]

pipe_log_model = Pipeline(steps=operations)

# %%
pipe_log_model.fit(X_train,y_train)
eval_metric(pipe_log_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[241  12   7]
#  [  5 111  20]
#  [ 25  91 642]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.93      0.91       260
#     Hispanic       0.52      0.82      0.63       136
#        White       0.96      0.85      0.90       758
#
#     accuracy                           0.86      1154
#    macro avg       0.79      0.86      0.81      1154
# weighted avg       0.89      0.86      0.87      1154
#
#
# Train_Set
# [[ 971   38   29]
#  [  21  456   66]
#  [  60  358 2616]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.94      0.93      1038
#     Hispanic       0.54      0.84      0.65       543
#        White       0.96      0.86      0.91      3034
#
#     accuracy                           0.88      4615
#    macro avg       0.81      0.88      0.83      4615
# weighted avg       0.90      0.88      0.88      4615

# %%
from sklearn.metrics import make_scorer
scoring = {"f1_Hispanic" : make_scorer(f1_score, average = None, labels =["Hispanic"]),
           "precision_Hispanic" : make_scorer(precision_score, average = None, labels =["Hispanic"]),
           "recall_Hispanic" : make_scorer(recall_score, average = None, labels =["Hispanic"])}

# %%
operations = [("OneHotEncoder", column_trans), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,
                                                                          random_state=101))]

model = Pipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.603480
# test_precision_Hispanic    0.493124
# test_recall_Hispanic       0.780707
# dtype: float64

# %% [markdown]
# ### Logistic Model GridsearchCV

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
operations = [("OneHotEncoder", column_trans), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,
                                                                          random_state=101))]

model = Pipeline(steps=operations)

# %%
recall_Hispanic = make_scorer(recall_score, average = None, labels =["Hispanic"])

# %%
from sklearn.model_selection import GridSearchCV
 
# l1: Lasso, l2: Ridge
penalty = ["l1", "l2"] 
# to get 20 values of C between -1 and 5
C = np.logspace(-1, 5, 20) 
# balanced: class weights are balanced, None: no class weights
class_weight= ["balanced", None] 
# to get 4 values of solver
solver = ["lbfgs", "liblinear", "sag", "saga"] 
# to get all the combinations of penalty, C, class_weight and solver
param_grid = {"log_model__penalty" : penalty,
              "log_model__C" : [C,1],
              "log_model__class_weight":class_weight,
              "log_model__solver":solver}

# %%
param_grid = {
    "log__C": [1, 5, 10],
    'log__penalty': ["l1", "l2"],
    'log__solver': ['liblinear', 'lbfgs'],
}

# %%
log_model_grid = GridSearchCV(model,
                              param_grid,
                              verbose=2,
                              scoring=recall_Hispanic,
                              n_jobs=-1, cv=5)

# %%
log_model_grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('OneHotEncoder',
#                                         ColumnTransformer(remainder=MinMaxScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          [])])),
#                                        ('log',
#                                         LogisticRegression(class_weight='balanced',
#                                                            max_iter=10000,
#                                                            random_state=101))]),
#              n_jobs=-1,
#              param_grid={'log__C': [1, 5, 10], 'log__penalty': ['l1', 'l2'],
#                          'log__solver': ['liblinear', 'lbfgs']},
#              scoring=make_scorer(recall_score, average=None, labels=['Hispanic']),
#              verbose=2)

# %%
#grid_model.fit(X_train,y_train)

# %%
log_model_grid.best_params_ # to get the best parameters according to the best score
# Out:
# {'log__C': 1, 'log__penalty': 'l2', 'log__solver': 'lbfgs'}

# %%
eval_metric(log_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[241  12   7]
#  [  5 111  20]
#  [ 25  91 642]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.93      0.91       260
#     Hispanic       0.52      0.82      0.63       136
#        White       0.96      0.85      0.90       758
#
#     accuracy                           0.86      1154
#    macro avg       0.79      0.86      0.81      1154
# weighted avg       0.89      0.86      0.87      1154
#
#
# Train_Set
# [[ 971   38   29]
#  [  21  456   66]
#  [  60  358 2616]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.94      0.93      1038
#     Hispanic       0.54      0.84      0.65       543
#        White       0.96      0.86      0.91      3034
#
#     accuracy                           0.88      4615
#    macro avg       0.81      0.88      0.83      4615
# weighted avg       0.90      0.88      0.88      4615

# %%
from yellowbrick.classifier import PrecisionRecallCurve

operations = [("OneHotEncoder", column_trans), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,
                                                                          random_state=101))]

model = Pipeline(steps=operations)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
y_pred = log_model_grid.predict(X_test)

log_AP = viz.score_["Hispanic"]
log_f1 = f1_score(y_test, y_pred, average=None, labels=["Hispanic"])
log_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# ## 2. SVC

# %% [markdown]
# ### Vanilla SVC model

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report,confusion_matrix

# %%
operations_svc = [('OneHotEncoder',column_trans),("svc", SVC(class_weight="balanced",random_state=101))]
pipe_svc_model = Pipeline(steps=operations_svc)

# %%
pipe_svc_model.fit(X_train, y_train)

eval_metric(pipe_svc_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[240  12   8]
#  [  5 111  20]
#  [ 18 111 629]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.92      0.92       260
#     Hispanic       0.47      0.82      0.60       136
#        White       0.96      0.83      0.89       758
#
#     accuracy                           0.85      1154
#    macro avg       0.78      0.86      0.80      1154
# weighted avg       0.89      0.85      0.86      1154
#
#
# Train_Set
# [[ 957   40   41]
#  [  24  454   65]
#  [  53  422 2559]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.92      0.92      1038
#     Hispanic       0.50      0.84      0.62       543
#        White       0.96      0.84      0.90      3034
#
#     accuracy                           0.86      4615
#    macro avg       0.79      0.87      0.81      4615
# weighted avg       0.90      0.86      0.87      4615

# %%
model = Pipeline(steps=operations_svc)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 5)
df_scores = pd.DataFrame(scores, index = range(1, 6))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.569342
# test_precision_Hispanic    0.452816
# test_recall_Hispanic       0.767907
# dtype: float64

# %% [markdown]
# ###  SVC Model GridsearchCV

# %%
param_grid = {
    'svc__C': [3,4,5],
    'svc__gamma': ["scale", "auto", 1, 0.1]
}

# %%
operations_svc = [("OneHotEncoder", column_trans), ("svc", SVC(class_weight="balanced",random_state=101))]

model = Pipeline(steps=operations_svc)

svm_model_grid = GridSearchCV(model,
                              param_grid,
                              verbose=3,
                              scoring=recall_Hispanic,
                              n_jobs=-1)

# %%
svm_model_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=Pipeline(steps=[('OneHotEncoder',
#                                         ColumnTransformer(remainder=MinMaxScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          [])])),
#                                        ('svc',
#                                         SVC(class_weight='balanced',
#                                             random_state=101))]),
#              n_jobs=-1,
#              param_grid={'svc__C': [3, 4, 5],
#                          'svc__gamma': ['scale', 'auto', 1, 0.1]},
#              scoring=make_scorer(recall_score, average=None, labels=['Hispanic']),
#              verbose=3)

# %%
svm_model_grid.best_params_
# Out:
# {'svc__C': 4, 'svc__gamma': 'scale'}

# %%
svm_model_grid.best_score_
# Out:
# 0.7586816173972137

# %%
eval_metric(svm_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[239  11  10]
#  [  5 109  22]
#  [ 22  86 650]]
#               precision    recall  f1-score   support
#
#        Black       0.90      0.92      0.91       260
#     Hispanic       0.53      0.80      0.64       136
#        White       0.95      0.86      0.90       758
#
#     accuracy                           0.86      1154
#    macro avg       0.79      0.86      0.82      1154
# weighted avg       0.89      0.86      0.87      1154
#
#
# Train_Set
# [[ 979   28   31]
#  [  13  476   54]
#  [  43  320 2671]]
#               precision    recall  f1-score   support
#
#        Black       0.95      0.94      0.94      1038
#     Hispanic       0.58      0.88      0.70       543
#        White       0.97      0.88      0.92      3034
#
#     accuracy                           0.89      4615
#    macro avg       0.83      0.90      0.85      4615
# weighted avg       0.92      0.89      0.90      4615

# %%
operations_svc = [("OneHotEncoder", column_trans), ("svc", SVC(C=4, class_weight="balanced",random_state=101))]

model = Pipeline(steps=operations_svc)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
y_pred = svm_model_grid.predict(X_test)

svc_AP = viz.score_["Hispanic"]
svc_f1 = f1_score(y_test, y_pred, average=None, labels=["Hispanic"])
svc_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# ## 3. RF

# %% [markdown]
# ### Vanilla RF Model

# %%
cat = X.select_dtypes("object").columns
cat
# Out:
# Index(['Gender', 'SubjectsBirthLocation'], dtype='object')

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OrdinalEncoder
ord_enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
column_trans = make_column_transformer((ord_enc, cat), remainder='passthrough')

# %%
X = soldiers2.drop("DODRace",axis=1)
y = soldiers2.DODRace

# %%
enc = OrdinalEncoder()
X[cat] = enc.fit_transform(X[cat])
X.head()
# Out:
#    abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0                             266            1467                    337                 222          1347                      253               202                401                        369               274               493                  71               319                        291                 142                   979           240            882                619                     509                373             1535           291                1074         259         1292           877                    607                             351          36         71             19              247               802                    101         273                        349                         299                    575                477                 1136           90                214         193          150                583         206                     326           70         332                366                1071
# 1                             233            1395                    326                 220          1293                      245               193                394                        338               257               479                  67               344                        320                 135                   944           232            870                584                     468                357             1471           269                1021         253         1244           851                    615                             376          33         62             18              232               781                     98         263                        348                         289                    523                476                 1096           86                203         195          146                568         201                     334           72         312                356                1046
# 2                             287            1430                    341                 230          1327                      256               196                427                        408               261               544                  75               345                        330                 135                  1054           258            901                623                     506                412             1501           288                1120         267         1288           854                    636                             359          40         61             23              237               810                    103         270                        355                         357                    575                491                 1115           93                220         203          148                573         202                     356           70         349                393                1053
# 3                             234            1347                    310                 230          1239                      262               199                401                        359               262               518                  73               328                        309                 143                   991           242            821                560                     437                395             1423           296                1114         262         1205           769                    590                             341          39         66             25              272               794                    106         267                        352                         318                    593                467                 1034           91                217         194          158                576         199                     341           68         338                367                 986
# 4                             250            1585                    372                 247          1478                      267               224                435                        356               263               524                  80               340                        310                 138                  1029           275           1080                706                     567                425             1684           304                1048         232         1452          1014                    682                             382          32         56             19              188               814                    111         305                        399                         324                    605                550                 1279           94                222         218          153                566         197                     374           69         332                372                1251
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  weightkg  wristcircumference  wristheight  Gender  SubjectsBirthLocation  SubjectNumericRace  Age
# 0                    685         422          441                   502                560                             500                      77                      391                  118                400                    436                           1447         113              437                   273                   1151                  368             145            928                     883            600  1782     1776                 1449            1092                 610             164            786           491               140                  919                           1700              501           329                 933         240                      440                  1054       815                 175          853     1.0                   91.0                   1   41
# 1                    620         441          447                   490                540                             488                      73                      371                  131                380                    420                           1380         118              417                   254                   1119                  353             141            884                     868            564  1745     1702                 1387            1076                 572             169            822           476               120                  918                           1627              432           316                 870         225                      371                  1054       726                 167          815     1.0                   86.0                   1   35
# 2                    665         462          475                   496                556                             482                      72                      409                  123                403                    434                           1447         121              431                   268                   1276                  367             167            917                     910            604  1867     1735                 1438            1105                 685             198            807           477               125                  918                           1678              472           329                 964         255                      411                  1041       929                 180          831     1.0                   86.0                   2   42
# 3                    640         458          461                   460                511                             452                      76                      393                  106                407                    446                           1357         118              393                   249                   1155                  330             148            903                     848            550  1708     1655                 1346            1021                 604             180            803           445               127                  847                           1625              461           315                 857         205                      399                   968       794                 176          793     1.0                  133.0                   1   31
# 4                    675         481          505                   612                666                             585                      85                      458                  135                398                    430                           1572         132              523                   302                   1231                  400             180            919                     995            641  2035     1914                 1596            1292                 672             194            962           584               122                 1090                           1679              467           303                 868         214                      379                  1245       946                 188          954     1.0                   90.0                   2   21

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101, stratify =y)

# %%
print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (4615, 97)
# Train target shape   :  (4615,)
# Test features shape  :  (1154, 97)
# Test target shape    :  (1154,)

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier


operations_rf = [("OrdinalEncoder", column_trans), ("RF_model", RandomForestClassifier(class_weight="balanced", 
                                                                                    random_state=101))]

pipe_model_rf = Pipeline(steps=operations_rf)

pipe_model_rf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['Gender', 'SubjectsBirthLocation'], dtype='object'))])),
#                 ('RF_model',
#                  RandomForestClassifier(class_weight='balanced',
#                                         random_state=101))])

# %%
eval_metric(pipe_model_rf, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[242   7  11]
#  [ 19  86  31]
#  [ 11  15 732]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.93      0.91       260
#     Hispanic       0.80      0.63      0.70       136
#        White       0.95      0.97      0.96       758
#
#     accuracy                           0.92      1154
#    macro avg       0.88      0.84      0.86      1154
# weighted avg       0.92      0.92      0.92      1154
#
#
# Train_Set
# [[1038    0    0]
#  [   0  543    0]
#  [   0    0 3034]]
#               precision    recall  f1-score   support
#
#        Black       1.00      1.00      1.00      1038
#     Hispanic       1.00      1.00      1.00       543
#        White       1.00      1.00      1.00      3034
#
#     accuracy                           1.00      4615
#    macro avg       1.00      1.00      1.00      4615
# weighted avg       1.00      1.00      1.00      4615

# %%
operations_rf = [("OrdinalEncoder", column_trans), ("RF_model", RandomForestClassifier(class_weight="balanced", 
                                                                                    random_state=101))]

model = Pipeline(steps=operations_rf)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 5)
df_scores = pd.DataFrame(scores, index = range(1, 6))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.726698
# test_precision_Hispanic    0.855109
# test_recall_Hispanic       0.633571
# dtype: float64

# %% [markdown]
# ### RF Model GridsearchCV

# %%
param_grid = {'RF_model__n_estimators':[420,470],
             'RF_model__max_depth':[6,8]} #'min_samples_split':[18,20,22], 'max_features': ['auto', None, 15, 20]

# %%
operations_rf = [("OrdinalEncoder", column_trans), ("RF_model", RandomForestClassifier(class_weight="balanced", 
                                                                                    random_state=101))]

model = Pipeline(steps=operations_rf)
rf_grid_model = GridSearchCV(model,
                             param_grid,
                             verbose=3,
                             scoring=recall_Hispanic,
                             n_jobs=-1)

# %%
rf_grid_model.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# GridSearchCV(estimator=Pipeline(steps=[('OrdinalEncoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinalencoder',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          Index(['Gender', 'SubjectsBirthLocation'], dtype='object'))])),
#                                        ('RF_model',
#                                         RandomForestClassifier(class_weight='balanced',
#                                                                random_state=101))]),
#              n_jobs=-1,
#              param_grid={'RF_model__max_depth': [6, 8],
#                          'RF_model__n_estimators': [420, 470]},
#              scoring=make_scorer(recall_score, average=None, labels=['Hispanic']),
#              verbose=3)

# %%
rf_grid_model.best_estimator_
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['Gender', 'SubjectsBirthLocation'], dtype='object'))])),
#                 ('RF_model',
#                  RandomForestClassifier(class_weight='balanced', max_depth=6,
#                                         n_estimators=470, random_state=101))])

# %%
rf_grid_model.best_params_
# Out:
# {'RF_model__max_depth': 6, 'RF_model__n_estimators': 470}

# %%
rf_grid_model.best_score_
# Out:
# 0.8379714576962284

# %%
eval_metric(rf_grid_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[236  21   3]
#  [ 16 115   5]
#  [  9  45 704]]
#               precision    recall  f1-score   support
#
#        Black       0.90      0.91      0.91       260
#     Hispanic       0.64      0.85      0.73       136
#        White       0.99      0.93      0.96       758
#
#     accuracy                           0.91      1154
#    macro avg       0.84      0.89      0.86      1154
# weighted avg       0.93      0.91      0.92      1154
#
#
# Train_Set
# [[ 983   53    2]
#  [  25  513    5]
#  [  22  129 2883]]
#               precision    recall  f1-score   support
#
#        Black       0.95      0.95      0.95      1038
#     Hispanic       0.74      0.94      0.83       543
#        White       1.00      0.95      0.97      3034
#
#     accuracy                           0.95      4615
#    macro avg       0.90      0.95      0.92      4615
# weighted avg       0.96      0.95      0.95      4615

# %%
from yellowbrick.classifier import PrecisionRecallCurve

# %%
operations_rf = [("OrdinalEncoder", column_trans), ("RF_model", RandomForestClassifier(class_weight="balanced", 
                                                    max_depth=2, n_estimators=400, random_state=101))]

model = Pipeline(steps=operations_rf)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
y_pred = rf_grid_model.predict(X_test)

rf_AP = viz.score_["Hispanic"]
rf_f1 = f1_score(y_test, y_pred, average=None, labels=["Hispanic"])
rf_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# ## 4. XGBoost

# %% [markdown]
# ### Vanilla XGBoost Model

# %%
# !pip install xgboost==0.90

# %%
import xgboost as xgb

xgb.__version__
# Out:
# '0.90'

# %%
from xgboost import XGBClassifier

# %%
operations_xgb = [("OrdinalEncoder", column_trans), ("XGB_model", XGBClassifier(random_state=101))]

pipe_model_xgb = Pipeline(steps=operations_xgb)

pipe_model_xgb.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['Gender', 'SubjectsBirthLocation'], dtype='object'))])),
#                 ('XGB_model',
#                  XGBClassifier(objective='multi:softprob', random_state=101))])

# %%
from sklearn.utils import class_weight
classes_weights = class_weight.compute_sample_weight(class_weight='balanced', y=y_train)
classes_weights
# Out:
# array([2.8330264 , 0.50703142, 0.50703142, ..., 0.50703142, 1.4820167 ,
#        0.50703142])

# %%
comp = pd.DataFrame(classes_weights)

comp["label"] = y_train.reset_index(drop=True)
comp.groupby("label")[0].value_counts()
# Out:
# label     0
# Black     1.482017    1038
# Hispanic  2.833026     543
# White     0.507031    3034
# Name: 0, dtype: int64

# %%
pipe_model_xgb.fit(X_train,y_train, XGB_model__sample_weight=classes_weights)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['Gender', 'SubjectsBirthLocation'], dtype='object'))])),
#                 ('XGB_model',
#                  XGBClassifier(objective='multi:softprob', random_state=101))])

# %%
eval_metric(pipe_model_xgb, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[250   5   5]
#  [  0 136   0]
#  [ 12  17 729]]
#               precision    recall  f1-score   support
#
#        Black       0.95      0.96      0.96       260
#     Hispanic       0.86      1.00      0.93       136
#        White       0.99      0.96      0.98       758
#
#     accuracy                           0.97      1154
#    macro avg       0.94      0.97      0.95      1154
# weighted avg       0.97      0.97      0.97      1154
#
#
# Train_Set
# [[1036    2    0]
#  [   0  543    0]
#  [  21   50 2963]]
#               precision    recall  f1-score   support
#
#        Black       0.98      1.00      0.99      1038
#     Hispanic       0.91      1.00      0.95       543
#        White       1.00      0.98      0.99      3034
#
#     accuracy                           0.98      4615
#    macro avg       0.96      0.99      0.98      4615
# weighted avg       0.99      0.98      0.98      4615

# %%
operations_xgb = [("OrdinalEncoder", column_trans), ("XGB_model", XGBClassifier(random_state=101))]

model = Pipeline(steps=operations_xgb)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 5,
                        fit_params={"XGB_model__sample_weight":classes_weights})
df_scores = pd.DataFrame(scores, index = range(1, 6))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.907483
# test_precision_Hispanic    0.873279
# test_recall_Hispanic       0.946619
# dtype: float64

# %%
operations_xgb = [("OrdinalEncoder", column_trans), ("XGB_model", XGBClassifier(random_state=101))]

model = Pipeline(steps=operations_xgb)

scores = cross_validate(model, X_train, y_train, scoring = None, cv = 5,
                        fit_params={"XGB_model__sample_weight":classes_weights})
df_scores = pd.DataFrame(scores, index = range(1, 6))
df_scores.mean()[2:]
# Out:
# test_score    0.971398
# dtype: float64

# %% [markdown]
# ### XGBoost Model GridsearchCV

# %%
param_grid = {"XGB_model__n_estimators":[40, 60],
              'XGB_model__max_depth':[2,3],
              "XGB_model__learning_rate": [0.2, 0.5],
              "XGB_model__subsample":[0.6, 0.9],
              "XGB_model__colsample_bytree":[0.6, 0.9]}

# %%
operations_xgb = [("OrdinalEncoder", column_trans), ("XGB_model", XGBClassifier(random_state=101))]

model = Pipeline(steps=operations_xgb)

xgb_grid_model = GridSearchCV(model, 
                              param_grid, 
                              scoring=recall_Hispanic, 
                              n_jobs = -1, 
                              verbose = 2).fit(X_train, y_train, XGB_model__sample_weight=classes_weights)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits

# %%
xgb_grid_model.best_estimator_
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['Gender', 'SubjectsBirthLocation'], dtype='object'))])),
#                 ('XGB_model',
#                  XGBClassifier(colsample_bytree=0.6, learning_rate=0.2,
#                                max_depth=2, n_estimators=40,
#                                objective='multi:softprob', random_state=101,
#                                subsample=0.6))])

# %%
xgb_grid_model.best_params_
# Out:
# {'XGB_model__colsample_bytree': 0.6,
#  'XGB_model__learning_rate': 0.2,
#  'XGB_model__max_depth': 2,
#  'XGB_model__n_estimators': 40,
#  'XGB_model__subsample': 0.6}

# %%
xgb_grid_model.best_score_
# Out:
# 0.9539925246347265

# %%
eval_metric(xgb_grid_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[247  10   3]
#  [  1 134   1]
#  [ 10  30 718]]
#               precision    recall  f1-score   support
#
#        Black       0.96      0.95      0.95       260
#     Hispanic       0.77      0.99      0.86       136
#        White       0.99      0.95      0.97       758
#
#     accuracy                           0.95      1154
#    macro avg       0.91      0.96      0.93      1154
# weighted avg       0.96      0.95      0.95      1154
#
#
# Train_Set
# [[1013   22    3]
#  [   9  530    4]
#  [  18   87 2929]]
#               precision    recall  f1-score   support
#
#        Black       0.97      0.98      0.97      1038
#     Hispanic       0.83      0.98      0.90       543
#        White       1.00      0.97      0.98      3034
#
#     accuracy                           0.97      4615
#    macro avg       0.93      0.97      0.95      4615
# weighted avg       0.97      0.97      0.97      4615

# %%
# !pip install scikit-plot

# %%
from scikitplot.metrics import plot_roc, precision_recall_curve
from scikitplot.metrics import plot_precision_recall
from sklearn.metrics import classification_report,confusion_matrix,plot_confusion_matrix, average_precision_score

perations_xgb = [("OrdinalEncoder", column_trans), ("XGB_model", XGBClassifier(learning_rate=0.3, max_depth=1,
                            random_state=101, subsample=0.8))]

model = Pipeline(steps=operations_xgb)

model.fit(X_train, y_train, XGB_model__sample_weight=classes_weights)

y_pred_proba = model.predict_proba(X_test)
#y_pred = model.predict(X_test)
#Plot metrics 
#plot_roc(y_test, y_score)
#plt.show()
    
plot_precision_recall(y_test, y_pred_proba)
plt.show()

# %%
y_test_dummies = pd.get_dummies(y_test, drop_first=False).values

average_precision_score(y_test_dummies[:, 1], y_pred_proba[:, 1])
# Out:
# 0.9721887064639066

# %%
y_pred = xgb_grid_model.predict(X_test)

xgb_AP = average_precision_score(y_test_dummies[:, 1], y_pred_proba[:, 1])
xgb_f1 = f1_score(y_test, y_pred, average=None, labels=["Hispanic"])
xgb_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# ## Comparing Models

# %%
compare = pd.DataFrame({"Model": ["Logistic Regression", "SVM",  "Random Forest", "XGBoost"],
                        "F1": [log_f1[0], svc_f1[0], rf_f1[0], xgb_f1[0]],
                        "Recall": [log_recall[0], svc_recall[0], rf_recall[0], xgb_recall[0]],
                        "AP": [log_AP, svc_AP, rf_AP, xgb_AP]})

def labels(ax):
    for p in ax.patches:
        width = p.get_width()                        # get bar length
        ax.text(width,                               # set the text at 1 unit right of the bar
                p.get_y() + p.get_height() / 2,      # get Y coordinate + X coordinate / 2
                '{:1.3f}'.format(width),             # set variable to display, 2 decimals
                ha = 'left',                         # horizontal alignment
                va = 'center')                       # vertical alignment
    
plt.figure(figsize=(14,10))
plt.subplot(311)
compare = compare.sort_values(by="F1", ascending=False)
ax=sns.barplot(x="F1", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(312)
compare = compare.sort_values(by="Recall", ascending=False)
ax=sns.barplot(x="Recall", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(313)
compare = compare.sort_values(by="AP", ascending=False)
ax=sns.barplot(x="AP", y="Model", data=compare, palette="Blues_d")
labels(ax)
plt.show()

# %% [markdown]
# ---
# ---

# %% [markdown]
# ---
# ---

# %% [markdown]
# # SMOTE
# https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

# %% [markdown]
# ##  Smote implement

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as imbpipeline

# %% [markdown]
# ## SVC Over/Under Sampling

# %%
column_trans = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat), 
                                       remainder=MinMaxScaler())

# %%
X_train_ohe = column_trans.fit_transform(X_train)

# %%
over = SMOTE()
X_over, y_over = over.fit_resample(X_train_ohe, y_train)

# %%
X_over.shape
# Out:
# (9102, 225)

# %%
y_over.value_counts()
# Out:
# Hispanic    3034
# White       3034
# Black       3034
# Name: DODRace, dtype: int64

# %%
under = RandomUnderSampler()
X_under, y_under = under.fit_resample(X_train_ohe, y_train)

# %%
X_under.shape
# Out:
# (1629, 225)

# %%
y_under.value_counts()
# Out:
# Black       543
# Hispanic    543
# White       543
# Name: DODRace, dtype: int64

# %%
over = SMOTE(sampling_strategy={"Hispanic": 1000})
under = RandomUnderSampler(sampling_strategy={"White": 2500})

# %%
X_resampled_over, y_resampled_over = over.fit_resample(X_train_ohe, y_train)

# %%
y_train.value_counts()
# Out:
# White       3034
# Black       1038
# Hispanic     543
# Name: DODRace, dtype: int64

# %%
y_resampled_over.value_counts()
# Out:
# White       3034
# Black       1038
# Hispanic    1000
# Name: DODRace, dtype: int64

# %%
X_resampled_under, y_resampled_under = under.fit_resample(X_train_ohe, y_train)

# %%
y_resampled_under.value_counts()
# Out:
# White       2500
# Black       1038
# Hispanic     543
# Name: DODRace, dtype: int64

# %%
# we are configuring our pipeline steps
steps = [('o', over), ('u', under)]

# create a pipeline that will automatically apply over and under
# sampling in order to steps that we created.
pipeline = imbpipeline(steps=steps)

# we will create new data over X_train and y_train.
# We simply delete some of our samples if its race "white" and we add synthetic samples to "hispanics".
X_resampled, y_resampled = pipeline.fit_resample(X_train_ohe, y_train)

# %%
y_resampled.value_counts()
# Out:
# White       2500
# Black       1038
# Hispanic    1000
# Name: DODRace, dtype: int64

# %%
y_train.value_counts()
# Out:
# White       3034
# Black       1038
# Hispanic     543
# Name: DODRace, dtype: int64

# %% [markdown]
# ## Xgboost Over/ Under Sampling

# %% [markdown]
# - Evaluation metrics
# https://towardsdatascience.com/comprehensive-guide-on-multiclass-classification-metrics-af94cfb83fbd

# %%
from sklearn.metrics import matthews_corrcoef

matthews_corrcoef(y_test, y_pred)
# Out:
# 0.9107348339361192

# %%
from sklearn.metrics import cohen_kappa_score

cohen_kappa_score(y_test, y_pred)
# Out:
# 0.9085045899068179

# %%
column_trans = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat), 
                                       remainder=MinMaxScaler())

# %%
operations = [("OneHotEncoder",column_trans), ('o', over), ('u', under), 
              ("log", LogisticRegression(max_iter=10000,random_state=101))] #("scaler", MinMaxScaler())

# %%
smote_pipeline = imbpipeline(steps=operations)

# %%
smote_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['Gender', 'SubjectsBirthLocation'], dtype='object'))])),
#                 ('o', SMOTE(sampling_strategy={'Hispanic': 1000})),
#                 ('u', RandomUnderSampler(sampling_strategy={'White': 2500})),
#                 ('log', LogisticRegression(max_iter=10000, random_state=101))])

# %%
eval_metric(smote_pipeline, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[236   8  16]
#  [  3 100  33]
#  [ 14  41 703]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.91      0.92       260
#     Hispanic       0.67      0.74      0.70       136
#        White       0.93      0.93      0.93       758
#
#     accuracy                           0.90      1154
#    macro avg       0.85      0.86      0.85      1154
# weighted avg       0.90      0.90      0.90      1154
#
#
# Train_Set
# [[ 949   30   59]
#  [  22  389  132]
#  [  29  156 2849]]
#               precision    recall  f1-score   support
#
#        Black       0.95      0.91      0.93      1038
#     Hispanic       0.68      0.72      0.70       543
#        White       0.94      0.94      0.94      3034
#
#     accuracy                           0.91      4615
#    macro avg       0.85      0.86      0.86      4615
# weighted avg       0.91      0.91      0.91      4615

# %%
model = imbpipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.644084
# test_precision_Hispanic    0.637602
# test_recall_Hispanic       0.653670
# dtype: float64

# %% [markdown]
# #  SHAP
#
# https://towardsdatascience.com/shap-explain-any-machine-learning-model-in-python-24207127cad7

# %%
# !pip install shap

# %%
#import shap
#explainer = shap.Explainer(pipe_log_model,X_train)
#start_index = 203
#end_index = 204
#shap_values = explainer.shap_values(X_test[start_index:end_index])

# %%
#shap_values

# %%
#print(shap_values[0].shape)

# %%
# %% >> Visualize local predictions
#shap.initjs()
# Force plot
#prediction = log_model.predict(X_test[start_index:end_index])[0]
#print(f"The log_model predicted: {prediction}")
#shap.force_plot(explainer.expected_value[1],
                #shap_values[1],
                #X_test[start_index:end_index], # for values
                #feature_names= X.columns,)

# %%
#shap.summary_plot(shap_values, X_train,max_display=300,feature_names = X.columns)

# %%
column_trans_shap = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat), 
                                       remainder=MinMaxScaler())

X_train_trans = column_trans_shap.fit_transform(X_train)
X_test_trans = column_trans_shap.transform(X_test)

model_shap = LogisticRegression(class_weight='balanced',max_iter=10000, random_state=101, penalty="l1", solver='saga')

model_shap.fit(X_train_trans, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=10000, penalty='l1',
#                    random_state=101, solver='saga')

# %%
X_train_trans
# Out:
# array([[0.00000000e+00, 1.00000000e+00, 0.00000000e+00, ...,
#         3.67601246e-01, 7.08382527e-04, 1.95121951e-01],
#        [0.00000000e+00, 1.00000000e+00, 0.00000000e+00, ...,
#         6.26168224e-01, 0.00000000e+00, 3.90243902e-01],
#        [0.00000000e+00, 1.00000000e+00, 0.00000000e+00, ...,
#         6.79127726e-01, 0.00000000e+00, 4.63414634e-01],
#        ...,
#        [0.00000000e+00, 1.00000000e+00, 0.00000000e+00, ...,
#         6.51090343e-01, 0.00000000e+00, 9.75609756e-02],
#        [1.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         3.17757009e-01, 2.36127509e-05, 1.46341463e-01],
#        [0.00000000e+00, 1.00000000e+00, 1.00000000e+00, ...,
#         5.01557632e-01, 0.00000000e+00, 2.92682927e-01]])

# %%
eval_metric(model_shap, X_train_trans, y_train, X_test_trans, y_test)
# Out:
# Test_Set
# [[242  10   8]
#  [  5 111  20]
#  [ 26  92 640]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.93      0.91       260
#     Hispanic       0.52      0.82      0.64       136
#        White       0.96      0.84      0.90       758
#
#     accuracy                           0.86      1154
#    macro avg       0.79      0.86      0.81      1154
# weighted avg       0.89      0.86      0.87      1154
#
#
# Train_Set
# [[ 972   34   32]
#  [  19  453   71]
#  [  64  350 2620]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.94      0.93      1038
#     Hispanic       0.54      0.83      0.66       543
#        White       0.96      0.86      0.91      3034
#
#     accuracy                           0.88      4615
#    macro avg       0.81      0.88      0.83      4615
# weighted avg       0.90      0.88      0.88      4615

# %%
model = LogisticRegression(class_weight='balanced',max_iter=10000, random_state=101, penalty="l1", solver='saga')

scores = cross_validate(model, X_train_trans, y_train, scoring = scoring, cv = 5)
df_scores = pd.DataFrame(scores, index = range(1, 6))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.594026
# test_precision_Hispanic    0.486588
# test_recall_Hispanic       0.764220
# dtype: float64

# %%
X_train.columns
# Out:
# Index(['abdominalextensiondepthsitting', 'acromialheight', 'acromionradialelength', 'anklecircumference', 'axillaheight', 'balloffootcircumference', 'balloffootlength', 'biacromialbreadth', 'bicepscircumferenceflexed', 'bicristalbreadth', 'bideltoidbreadth', 'bimalleolarbreadth', 'bitragionchinarc', 'bitragionsubmandibulararc', 'bizygomaticbreadth', 'buttockcircumference', 'buttockdepth', 'buttockheight', 'buttockkneelength', 'buttockpopliteallength', 'calfcircumference', 'cervicaleheight', 'chestbreadth', 'chestcircumference', 'chestdepth', 'chestheight', 'crotchheight', 'crotchlengthomphalion', 'crotchlengthposterioromphalion', 'earbreadth', 'earlength', 'earprotrusion', 'elbowrestheight', 'eyeheightsitting', 'footbreadthhorizontal', 'footlength', 'forearmcenterofgriplength', 'forearmcircumferenceflexed', 'forearmforearmbreadth', 'forearmhandlength', 'functionalleglength', 'handbreadth', 'handcircumference', 'handlength', 'headbreadth', 'headcircumference', 'headlength',
#        'heelanklecircumference', 'heelbreadth', 'hipbreadth', 'hipbreadthsitting', 'iliocristaleheight', 'interpupillarybreadth', 'interscyei', 'interscyeii', 'kneeheightmidpatella', 'kneeheightsitting', 'lateralfemoralepicondyleheight', 'lateralmalleolusheight', 'lowerthighcircumference', 'mentonsellionlength', 'neckcircumference', 'neckcircumferencebase', 'overheadfingertipreachsitting', 'palmlength', 'poplitealheight', 'radialestylionlength', 'shouldercircumference', 'shoulderelbowlength', 'shoulderlength', 'sittingheight', 'sleevelengthspinewrist', 'sleeveoutseam', 'span', 'stature', 'suprasternaleheight', 'tenthribheight', 'thighcircumference', 'thighclearance', 'thumbtipreach', 'tibialheight', 'tragiontopofhead', 'trochanterionheight', 'verticaltrunkcircumferenceusa', 'waistbacklength', 'waistbreadth', 'waistcircumference', 'waistdepth', 'waistfrontlengthsitting', 'waistheightomphalion', 'weightkg', 'wristcircumference', 'wristheight', 'Gender', 'SubjectsBirthLocation',
#        'SubjectNumericRace', 'Age'],
#       dtype='object')

# %%
features = column_trans_shap.get_feature_names_out(X_train.columns)
features
# Out:
# array(['onehotencoder__Gender_0.0', 'onehotencoder__Gender_1.0',
#        'onehotencoder__SubjectsBirthLocation_0.0',
#        'onehotencoder__SubjectsBirthLocation_1.0',
#        'onehotencoder__SubjectsBirthLocation_2.0',
#        'onehotencoder__SubjectsBirthLocation_3.0',
#        'onehotencoder__SubjectsBirthLocation_4.0',
#        'onehotencoder__SubjectsBirthLocation_5.0',
#        'onehotencoder__SubjectsBirthLocation_6.0',
#        'onehotencoder__SubjectsBirthLocation_7.0',
#        'onehotencoder__SubjectsBirthLocation_8.0',
#        'onehotencoder__SubjectsBirthLocation_9.0',
#        'onehotencoder__SubjectsBirthLocation_10.0',
#        'onehotencoder__SubjectsBirthLocation_11.0',
#        'onehotencoder__SubjectsBirthLocation_12.0',
#        'onehotencoder__SubjectsBirthLocation_13.0',
#        'onehotencoder__SubjectsBirthLocation_15.0',
#        'onehotencoder__SubjectsBirthLocation_16.0',
#        'onehotencoder__SubjectsBirthLocation_17.0',
#        'onehotencoder__SubjectsBirthLocation_18.0',
#        'onehotencoder__SubjectsBirthLocation_19.0',
#        'onehotencoder__SubjectsBirthLocation_20.0',
#        'onehotencoder__SubjectsBirthLocation_22.0',
#        'onehotencoder__SubjectsBirthLocation_23.0',
#        'onehotencoder__SubjectsBirthLocation_24.0',
#        'onehotencoder__SubjectsBirthLocation_25.0',
#        'onehotencoder__SubjectsBirthLocation_26.0',
#        'onehotencoder__SubjectsBirthLocation_27.0',
#        'onehotencoder__SubjectsBirthLocation_28.0',
#        'onehotencoder__SubjectsBirthLocation_29.0',
#        'onehotencoder__SubjectsBirthLocation_30.0',
#        'onehotencoder__SubjectsBirthLocation_32.0',
#        'onehotencoder__SubjectsBirthLocation_33.0',
#        'onehotencoder__SubjectsBirthLocation_34.0',
#        'onehotencoder__SubjectsBirthLocation_35.0',
#        'onehotencoder__SubjectsBirthLocation_36.0',
#        'onehotencoder__SubjectsBirthLocation_37.0',
#        'onehotencoder__SubjectsBirthLocation_38.0',
#        'onehotencoder__SubjectsBirthLocation_39.0',
#        'onehotencoder__SubjectsBirthLocation_40.0',
#        'onehotencoder__SubjectsBirthLocation_41.0',
#        'onehotencoder__SubjectsBirthLocation_42.0',
#        'onehotencoder__SubjectsBirthLocation_43.0',
#        'onehotencoder__SubjectsBirthLocation_44.0',
#        'onehotencoder__SubjectsBirthLocation_45.0',
#        'onehotencoder__SubjectsBirthLocation_47.0',
#        'onehotencoder__SubjectsBirthLocation_48.0',
#        'onehotencoder__SubjectsBirthLocation_49.0',
#        'onehotencoder__SubjectsBirthLocation_50.0',
#        'onehotencoder__SubjectsBirthLocation_51.0',
#        'onehotencoder__SubjectsBirthLocation_52.0',
#        'onehotencoder__SubjectsBirthLocation_53.0',
#        'onehotencoder__SubjectsBirthLocation_55.0',
#        'onehotencoder__SubjectsBirthLocation_56.0',
#        'onehotencoder__SubjectsBirthLocation_57.0',
#        'onehotencoder__SubjectsBirthLocation_58.0',
#        'onehotencoder__SubjectsBirthLocation_59.0',
#        'onehotencoder__SubjectsBirthLocation_60.0',
#        'onehotencoder__SubjectsBirthLocation_61.0',
#        'onehotencoder__SubjectsBirthLocation_62.0',
#        'onehotencoder__SubjectsBirthLocation_63.0',
#        'onehotencoder__SubjectsBirthLocation_64.0',
#        'onehotencoder__SubjectsBirthLocation_65.0',
#        'onehotencoder__SubjectsBirthLocation_66.0',
#        'onehotencoder__SubjectsBirthLocation_67.0',
#        'onehotencoder__SubjectsBirthLocation_68.0',
#        'onehotencoder__SubjectsBirthLocation_69.0',
#        'onehotencoder__SubjectsBirthLocation_70.0',
#        'onehotencoder__SubjectsBirthLocation_71.0',
#        'onehotencoder__SubjectsBirthLocation_72.0',
#        'onehotencoder__SubjectsBirthLocation_73.0',
#        'onehotencoder__SubjectsBirthLocation_74.0',
#        'onehotencoder__SubjectsBirthLocation_75.0',
#        'onehotencoder__SubjectsBirthLocation_76.0',
#        'onehotencoder__SubjectsBirthLocation_77.0',
#        'onehotencoder__SubjectsBirthLocation_78.0',
#        'onehotencoder__SubjectsBirthLocation_79.0',
#        'onehotencoder__SubjectsBirthLocation_80.0',
#        'onehotencoder__SubjectsBirthLocation_81.0',
#        'onehotencoder__SubjectsBirthLocation_82.0',
#        'onehotencoder__SubjectsBirthLocation_83.0',
#        'onehotencoder__SubjectsBirthLocation_84.0',
#        'onehotencoder__SubjectsBirthLocation_85.0',
#        'onehotencoder__SubjectsBirthLocation_86.0',
#        'onehotencoder__SubjectsBirthLocation_87.0',
#        'onehotencoder__SubjectsBirthLocation_88.0',
#        'onehotencoder__SubjectsBirthLocation_89.0',
#        'onehotencoder__SubjectsBirthLocation_90.0',
#        'onehotencoder__SubjectsBirthLocation_91.0',
#        'onehotencoder__SubjectsBirthLocation_92.0',
#        'onehotencoder__SubjectsBirthLocation_93.0',
#        'onehotencoder__SubjectsBirthLocation_94.0',
#        'onehotencoder__SubjectsBirthLocation_95.0',
#        'onehotencoder__SubjectsBirthLocation_96.0',
#        'onehotencoder__SubjectsBirthLocation_97.0',
#        'onehotencoder__SubjectsBirthLocation_98.0',
#        'onehotencoder__SubjectsBirthLocation_99.0',
#        'onehotencoder__SubjectsBirthLocation_100.0',
#        'onehotencoder__SubjectsBirthLocation_101.0',
#        'onehotencoder__SubjectsBirthLocation_102.0',
#        'onehotencoder__SubjectsBirthLocation_103.0',
#        'onehotencoder__SubjectsBirthLocation_104.0',
#        'onehotencoder__SubjectsBirthLocation_105.0',
#        'onehotencoder__SubjectsBirthLocation_106.0',
#        'onehotencoder__SubjectsBirthLocation_107.0',
#        'onehotencoder__SubjectsBirthLocation_108.0',
#        'onehotencoder__SubjectsBirthLocation_110.0',
#        'onehotencoder__SubjectsBirthLocation_111.0',
#        'onehotencoder__SubjectsBirthLocation_112.0',
#        'onehotencoder__SubjectsBirthLocation_113.0',
#        'onehotencoder__SubjectsBirthLocation_114.0',
#        'onehotencoder__SubjectsBirthLocation_115.0',
#        'onehotencoder__SubjectsBirthLocation_116.0',
#        'onehotencoder__SubjectsBirthLocation_118.0',
#        'onehotencoder__SubjectsBirthLocation_119.0',
#        'onehotencoder__SubjectsBirthLocation_120.0',
#        'onehotencoder__SubjectsBirthLocation_121.0',
#        'onehotencoder__SubjectsBirthLocation_122.0',
#        'onehotencoder__SubjectsBirthLocation_123.0',
#        'onehotencoder__SubjectsBirthLocation_124.0',
#        'onehotencoder__SubjectsBirthLocation_125.0',
#        'onehotencoder__SubjectsBirthLocation_126.0',
#        'onehotencoder__SubjectsBirthLocation_127.0',
#        'onehotencoder__SubjectsBirthLocation_128.0',
#        'onehotencoder__SubjectsBirthLocation_129.0',
#        'onehotencoder__SubjectsBirthLocation_130.0',
#        'onehotencoder__SubjectsBirthLocation_131.0',
#        'onehotencoder__SubjectsBirthLocation_132.0',
#        'onehotencoder__SubjectsBirthLocation_133.0',
#        'onehotencoder__SubjectsBirthLocation_134.0',
#        'remainder__abdominalextensiondepthsitting',
#        'remainder__acromialheight', 'remainder__acromionradialelength',
#        'remainder__anklecircumference', 'remainder__axillaheight',
#        'remainder__balloffootcircumference',
#        'remainder__balloffootlength', 'remainder__biacromialbreadth',
#        'remainder__bicepscircumferenceflexed',
#        'remainder__bicristalbreadth', 'remainder__bideltoidbreadth',
#        'remainder__bimalleolarbreadth', 'remainder__bitragionchinarc',
#        'remainder__bitragionsubmandibulararc',
#        'remainder__bizygomaticbreadth', 'remainder__buttockcircumference',
#        'remainder__buttockdepth', 'remainder__buttockheight',
#        'remainder__buttockkneelength',
#        'remainder__buttockpopliteallength',
#        'remainder__calfcircumference', 'remainder__cervicaleheight',
#        'remainder__chestbreadth', 'remainder__chestcircumference',
#        'remainder__chestdepth', 'remainder__chestheight',
#        'remainder__crotchheight', 'remainder__crotchlengthomphalion',
#        'remainder__crotchlengthposterioromphalion',
#        'remainder__earbreadth', 'remainder__earlength',
#        'remainder__earprotrusion', 'remainder__elbowrestheight',
#        'remainder__eyeheightsitting', 'remainder__footbreadthhorizontal',
#        'remainder__footlength', 'remainder__forearmcenterofgriplength',
#        'remainder__forearmcircumferenceflexed',
#        'remainder__forearmforearmbreadth', 'remainder__forearmhandlength',
#        'remainder__functionalleglength', 'remainder__handbreadth',
#        'remainder__handcircumference', 'remainder__handlength',
#        'remainder__headbreadth', 'remainder__headcircumference',
#        'remainder__headlength', 'remainder__heelanklecircumference',
#        'remainder__heelbreadth', 'remainder__hipbreadth',
#        'remainder__hipbreadthsitting', 'remainder__iliocristaleheight',
#        'remainder__interpupillarybreadth', 'remainder__interscyei',
#        'remainder__interscyeii', 'remainder__kneeheightmidpatella',
#        'remainder__kneeheightsitting',
#        'remainder__lateralfemoralepicondyleheight',
#        'remainder__lateralmalleolusheight',
#        'remainder__lowerthighcircumference',
#        'remainder__mentonsellionlength', 'remainder__neckcircumference',
#        'remainder__neckcircumferencebase',
#        'remainder__overheadfingertipreachsitting',
#        'remainder__palmlength', 'remainder__poplitealheight',
#        'remainder__radialestylionlength',
#        'remainder__shouldercircumference',
#        'remainder__shoulderelbowlength', 'remainder__shoulderlength',
#        'remainder__sittingheight', 'remainder__sleevelengthspinewrist',
#        'remainder__sleeveoutseam', 'remainder__span',
#        'remainder__stature', 'remainder__suprasternaleheight',
#        'remainder__tenthribheight', 'remainder__thighcircumference',
#        'remainder__thighclearance', 'remainder__thumbtipreach',
#        'remainder__tibialheight', 'remainder__tragiontopofhead',
#        'remainder__trochanterionheight',
#        'remainder__verticaltrunkcircumferenceusa',
#        'remainder__waistbacklength', 'remainder__waistbreadth',
#        'remainder__waistcircumference', 'remainder__waistdepth',
#        'remainder__waistfrontlengthsitting',
#        'remainder__waistheightomphalion', 'remainder__weightkg',
#        'remainder__wristcircumference', 'remainder__wristheight',
#        'remainder__SubjectNumericRace', 'remainder__Age'], dtype=object)

# %%
import shap

explainer = shap.LinearExplainer(model_shap, X_train_trans) #LinearExplainer

shap_values = explainer.shap_values(X_test_trans)

shap.summary_plot(shap_values, X_test_trans, max_display=300,feature_names = features, plot_type="bar")

# %%
explainer = shap.Explainer(model_shap, X_train_trans)

shap_values = explainer.shap_values(X_train_trans)

shap.summary_plot(shap_values, X_train_trans, max_display=300,feature_names = features)

# %%
hispanic = ["SubjectsBirthLocation",  'handlength',  'forearmcircumferenceflexed', "headlength", 'bitragionsubmandibulararc',
            'footbreadthhorizontal',  'bimalleolarbreadth', 'poplitealheight', 'waistdepth',  'tragiontopofhead',
            'bideltoidbreadth', 'neckcircumferencebase', 'biacromialbreadth','buttockheight', 'buttockkneelength', 'earlength', 
            'axillaheight', "Age"]

# %%
X2 = X[hispanic]
X2.head()
# Out:
#    SubjectsBirthLocation  handlength  forearmcircumferenceflexed  headlength  bitragionsubmandibulararc  footbreadthhorizontal  bimalleolarbreadth  poplitealheight  waistdepth  tragiontopofhead  bideltoidbreadth  neckcircumferencebase  biacromialbreadth  buttockheight  buttockkneelength  earlength  axillaheight  Age
# 0                   91.0         193                         299         206                        291                    101                  71              437         240               140               493                    436                401            882                619         71          1347   41
# 1                   86.0         195                         289         201                        320                     98                  67              417         225               120               479                    420                394            870                584         62          1293   35
# 2                   86.0         203                         357         202                        330                    103                  75              431         255               125               544                    434                427            901                623         61          1327   42
# 3                  133.0         194                         318         199                        309                    106                  73              393         205               127               518                    446                401            821                560         66          1239   31
# 4                   90.0         218                         324         197                        310                    111                  80              523         214               122               524                    430                435           1080                706         56          1478   21

# %%
X2 = X[hispanic]
y = soldiers2.DODRace

# %%
cat_new = X2.select_dtypes("object").columns
cat_new
# Out:
# Index([], dtype='object')

# %%
X2.shape
# Out:
# (5769, 18)

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y, test_size=0.2, random_state=101, stratify =y)

# %%
column_trans_shap = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat_new), 
                                       remainder=MinMaxScaler())

operations_shap = [("OneHotEncoder",column_trans_shap),("log", LogisticRegression(class_weight='balanced',max_iter=10000,
                                                            random_state=101, penalty="l1", solver='saga'))]

pipe_shap_model = Pipeline(steps=operations_shap)
pipe_shap_model.fit(X_train2, y_train2)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index([], dtype='object'))])),
#                 ('log',
#                  LogisticRegression(class_weight='balanced', max_iter=10000,
#                                     penalty='l1', random_state=101,
#                                     solver='saga'))])

# %%
eval_metric(pipe_shap_model, X_train2, y_train2, X_test2, y_test2)
# Out:
# Test_Set
# [[205  22  33]
#  [ 18  87  31]
#  [128 197 433]]
#               precision    recall  f1-score   support
#
#        Black       0.58      0.79      0.67       260
#     Hispanic       0.28      0.64      0.39       136
#        White       0.87      0.57      0.69       758
#
#     accuracy                           0.63      1154
#    macro avg       0.58      0.67      0.58      1154
# weighted avg       0.74      0.63      0.65      1154
#
#
# Train_Set
# [[ 812   92  134]
#  [  64  343  136]
#  [ 433  842 1759]]
#               precision    recall  f1-score   support
#
#        Black       0.62      0.78      0.69      1038
#     Hispanic       0.27      0.63      0.38       543
#        White       0.87      0.58      0.69      3034
#
#     accuracy                           0.63      4615
#    macro avg       0.59      0.66      0.59      4615
# weighted avg       0.74      0.63      0.66      4615

# %%
model = Pipeline(steps=operations_shap)

scores = cross_validate(model, X_train2, y_train2, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.375649
# test_precision_Hispanic    0.268369
# test_recall_Hispanic       0.628013
# dtype: float64

# %%
from yellowbrick.classifier import PrecisionRecallCurve
model = Pipeline(steps=operations_shap)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train2, y_train2)
viz.score(X_test2, y_test2)
viz.show();

# %%
from scikitplot.metrics import plot_roc, precision_recall_curve
from scikitplot.metrics import plot_precision_recall


model = Pipeline(steps=operations_shap)

model.fit(X_train2, y_train2)

y_pred_proba = model.predict_proba(X_test2)
    
plot_precision_recall(y_test2, y_pred_proba)
plt.show()

# %% [markdown]
# # Before the Deployment
# - Choose the model that works best based on your chosen metric
# - For final step, fit the best model with whole dataset to get better performance.
# - And your model ready to deploy, dump your model and scaler.

# %%
column_trans_final = make_column_transformer((ord_enc, cat), remainder='passthrough')

operations_final = [("OrdinalEncoder", column_trans), ("XGB_model", XGBClassifier(random_state=101))]

param_grid = {"XGB_model__colsample_bytree":[0.6],
              "XGB_model__learning_rate": [0.2],
              'XGB_model__max_depth':[2],
              "XGB_model__n_estimators":[40],
              "XGB_model__subsample":[0.6]
              }

with_xgb_model = Pipeline(steps=operations_final)

final_model = GridSearchCV(with_xgb_model, 
                              param_grid, 
                              scoring=recall_Hispanic, 
                              n_jobs = -1, 
                              verbose = 2)

# %%
# column_trans_final = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat), 
                                       #remainder=MinMaxScaler())

# operations_final = [("OneHotEncoder",column_trans_final),("log", LogisticRegression(class_weight='balanced',max_iter=10000,
                                                                          #random_state=101))]

# final_model = Pipeline(steps=operations_final)

# %%
final_model.fit(X, y)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# %%
mean_human = X.describe(include="all").loc["mean"]
mean_human
# Out:
# abdominalextensiondepthsitting     247.254290
# acromialheight                    1408.630265
# acromionradialelength              328.071590
# anklecircumference                 225.201768
# axillaheight                      1301.902583
# balloffootcircumference            244.408043
# balloffootlength                   195.118911
# biacromialbreadth                  399.706015
# bicepscircumferenceflexed          341.663027
# bicristalbreadth                   274.903449
# bideltoidbreadth                   491.454845
# bimalleolarbreadth                  72.335413
# bitragionchinarc                   324.962212
# bitragionsubmandibulararc          306.677760
# bizygomaticbreadth                 139.529381
# buttockcircumference              1022.059456
# buttockdepth                       242.234356
# buttockheight                      872.112845
# buttockkneelength                  610.449991
# buttockpopliteallength             498.331773
# calfcircumference                  386.316519
# cervicaleheight                   1479.952158
# chestbreadth                       283.232623
# chestcircumference                1024.206622
# chestdepth                         252.322586
# chestheight                       1254.290172
# crotchheight                       827.105738
# crotchlengthomphalion              622.693708
# crotchlengthposterioromphalion     351.880222
# earbreadth                          35.175420
# earlength                           62.606171
# earprotrusion                       22.227249
# elbowrestheight                    240.553302
# eyeheightsitting                   786.399203
# footbreadthhorizontal               98.915063
# footlength                         263.512394
# forearmcenterofgriplength          339.458832
# forearmcircumferenceflexed         295.661640
# forearmforearmbreadth              553.098284
# forearmhandlength                  467.898769
# functionalleglength               1104.347201
# handbreadth                         85.098111
# handcircumference                  204.215635
# handlength                         189.574796
# headbreadth                        152.043682
# headcircumference                  570.424337
# headlength                         196.640839
# heelanklecircumference             333.274918
# heelbreadth                         70.834113
# hipbreadth                         348.930837
# hipbreadthsitting                  386.417923
# iliocristaleheight                1042.152366
# interpupillarybreadth              632.534928
# interscyei                         412.773964
# interscyeii                        433.017334
# kneeheightmidpatella               476.665280
# kneeheightsitting                  541.376668
# lateralfemoralepicondyleheight     484.316693
# lateralmalleolusheight              69.761830
# lowerthighcircumference            406.943144
# mentonsellionlength                119.601664
# neckcircumference                  376.127578
# neckcircumferencebase              414.554516
# overheadfingertipreachsitting     1390.525048
# palmlength                         114.106604
# poplitealheight                    417.227076
# radialestylionlength               259.757670
# shouldercircumference             1131.214422
# shoulderelbowlength                354.805166
# shoulderlength                     145.202288
# sittingheight                      898.592477
# sleevelengthspinewrist             868.361068
# sleeveoutseam                      578.013001
# span                              1766.951118
# stature                           1716.938984
# suprasternaleheight               1405.392442
# tenthribheight                    1101.631479
# thighcircumference                 623.583637
# thighclearance                     176.696481
# thumbtipreach                      791.044548
# tibialheight                       459.389149
# tragiontopofhead                   129.580343
# trochanterionheight                884.659386
# verticaltrunkcircumferenceusa     1632.470966
# waistbacklength                    460.990293
# waistbreadth                       318.409950
# waistcircumference                 916.817126
# waistdepth                         230.459178
# waistfrontlengthsitting            377.352054
# waistheightomphalion              1033.591090
# weightkg                           800.981106
# wristcircumference                 169.308372
# wristheight                        831.334547
# Gender                               0.675854
# SubjectsBirthLocation               71.718495
# SubjectNumericRace                  16.894436
# Age                                 29.776391
# Name: mean, dtype: float64

# %%
mean_human["Gender"] = "Male"
mean_human["SubjectsBirthLocation"] = "California"
mean_human["WritingPreference"] = "Right hand"

# %%
pd.DataFrame(mean_human).T
# Out:
#      abdominalextensiondepthsitting acromialheight acromionradialelength anklecircumference axillaheight balloffootcircumference balloffootlength biacromialbreadth bicepscircumferenceflexed bicristalbreadth bideltoidbreadth bimalleolarbreadth bitragionchinarc bitragionsubmandibulararc bizygomaticbreadth buttockcircumference buttockdepth buttockheight buttockkneelength buttockpopliteallength calfcircumference cervicaleheight chestbreadth chestcircumference  chestdepth  chestheight crotchheight crotchlengthomphalion crotchlengthposterioromphalion earbreadth  earlength earprotrusion elbowrestheight eyeheightsitting footbreadthhorizontal  footlength forearmcenterofgriplength forearmcircumferenceflexed forearmforearmbreadth forearmhandlength functionalleglength handbreadth handcircumference  handlength headbreadth headcircumference  headlength heelanklecircumference heelbreadth  hipbreadth hipbreadthsitting iliocristaleheight interpupillarybreadth  interscyei interscyeii  \
# mean                      247.25429    1408.630265             328.07159         225.201768  1301.902583              244.408043       195.118911        399.706015                341.663027       274.903449       491.454845          72.335413       324.962212                 306.67776         139.529381          1022.059456   242.234356    872.112845        610.449991             498.331773        386.316519     1479.952158   283.232623        1024.206622  252.322586  1254.290172   827.105738            622.693708                     351.880222   35.17542  62.606171     22.227249      240.553302       786.399203             98.915063  263.512394                339.458832                  295.66164            553.098284        467.898769         1104.347201   85.098111        204.215635  189.574796  152.043682        570.424337  196.640839             333.274918   70.834113  348.930837        386.417923        1042.152366            632.534928  412.773964  433.017334
#
#      kneeheightmidpatella kneeheightsitting lateralfemoralepicondyleheight lateralmalleolusheight lowerthighcircumference mentonsellionlength neckcircumference neckcircumferencebase overheadfingertipreachsitting  palmlength poplitealheight radialestylionlength shouldercircumference shoulderelbowlength shoulderlength sittingheight sleevelengthspinewrist sleeveoutseam         span      stature suprasternaleheight tenthribheight thighcircumference thighclearance thumbtipreach tibialheight tragiontopofhead trochanterionheight verticaltrunkcircumferenceusa waistbacklength waistbreadth waistcircumference  waistdepth waistfrontlengthsitting waistheightomphalion    weightkg wristcircumference wristheight Gender SubjectsBirthLocation SubjectNumericRace        Age WritingPreference
# mean            476.66528        541.376668                     484.316693               69.76183              406.943144          119.601664        376.127578            414.554516                   1390.525048  114.106604      417.227076            259.75767           1131.214422          354.805166     145.202288    898.592477             868.361068    578.013001  1766.951118  1716.938984         1405.392442    1101.631479         623.583637     176.696481    791.044548   459.389149       129.580343          884.659386                   1632.470966      460.990293    318.40995         916.817126  230.459178              377.352054           1033.59109  800.981106         169.308372  831.334547   Male            California          16.894436  29.776391        Right hand

# %%
final_model.predict(pd.DataFrame(mean_human).T)
# Out:
# array(['Black'], dtype=object)

# %%
y[201]
# Out:
# 'Hispanic'

# %%
final_model.predict(X.loc[[201]])
# Out:
# array(['Hispanic'], dtype=object)

# %%
from sklearn.metrics import matthews_corrcoef

y_pred = final_model.predict(X_test)

matthews_corrcoef(y_test, y_pred)
# Out:
# 0.9366190785222257

# %%
from sklearn.metrics import cohen_kappa_score

cohen_kappa_score(y_test, y_pred)
# Out:
# 0.9365952897151851

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
